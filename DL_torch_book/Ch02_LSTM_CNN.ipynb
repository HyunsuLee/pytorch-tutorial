# %% [markdown]
# # Chaper 2 CNN과 LSTM 결합하기
# * https://github.com/PacktPublishing/Mastering-PyTorch/blob/master/Chapter02/image_captioning_pytorch.ipynb
# * COCO dataset을 HDD에 따로 받아 두었다. directory path는 아래 코드와 같다.
# * 총 용량이 20GB 가까이 되어(받는데 2시간 정도), 압축을 푸는데도 꽤 시간이 걸린다.
# * COCO dataset version은 2014년도 것이다. dataset이 조금더 작아서 학습하는데 시간이 덜걸린다.
# * 공식 [COCO dataset 홈피](https://cocodataset.org/#download)

# %%
coco_data = "/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO"

# %%
import os
import nltk
import pickle
import numpy as np
from PIL import Image
from collections import Counter
from pycocotools.coco import COCO
import matplotlib.pyplot as plt
 
import torch
import torch.nn as nn
import torch.utils.data as data
from torchvision import transforms
import torchvision.models as models
import torchvision.transforms as transforms
from torch.nn.utils.rnn import pack_padded_sequence

# %%
nltk.download('punkt') #tokenizer
# Out:
# [nltk_data] Downloading package punkt to /home/hyunsu/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# build vocabulary word to index and save as local pickle file
class Vocab(object):
    """Simple vocabulary wrapper."""
    def __init__(self):
        self.w2i = {}
        self.i2w = {}
        self.index = 0
 
    def __call__(self, token):
        if not token in self.w2i:
            return self.w2i['<unk>']
        return self.w2i[token]
 
    def __len__(self):
        return len(self.w2i)
    def add_token(self, token):
        if not token in self.w2i:
            self.w2i[token] = self.index
            self.i2w[self.index] = token
            self.index += 1

def build_vocabulary(json, threshold):
    """Build a simple vocabulary wrapper."""
    coco = COCO(json)
    counter = Counter()
    ids = coco.anns.keys()
    for i, id in enumerate(ids):
        caption = str(coco.anns[id]['caption'])
        tokens = nltk.tokenize.word_tokenize(caption.lower())
        counter.update(tokens)
 
        if (i+1) % 1000 == 0:
            print("[{}/{}] Tokenized the captions.".format(i+1, len(ids)))
 
    # If the word frequency is less than 'threshold', then the word is discarded.
    tokens = [token for token, cnt in counter.items() if cnt >= threshold]
 
    # Create a vocab wrapper and add some special tokens.
    vocab = Vocab()
    vocab.add_token('<pad>')
    vocab.add_token('<start>')
    vocab.add_token('<end>')
    vocab.add_token('<unk>')
 
    # Add the words to the vocabulary.
    for i, token in enumerate(tokens):
        vocab.add_token(token)
    return vocab

vocab = build_vocabulary(json=coco_data+'/annotations/captions_train2014.json', threshold=4)
vocab_path = coco_data+'/vocabulary.pkl'
with open(vocab_path, 'wb') as f:
    pickle.dump(vocab, f)
print("Total vocabulary size: {}".format(len(vocab)))
print("Saved the vocabulary wrapper to '{}'".format(vocab_path))
# Out:
# loading annotations into memory...
# Done (t=0.72s)
# creating index...
# index created!
# [1000/414113] Tokenized the captions.
# [2000/414113] Tokenized the captions.
# [3000/414113] Tokenized the captions.
# [4000/414113] Tokenized the captions.
# [5000/414113] Tokenized the captions.
# [6000/414113] Tokenized the captions.
# [7000/414113] Tokenized the captions.
# [8000/414113] Tokenized the captions.
# [9000/414113] Tokenized the captions.
# [10000/414113] Tokenized the captions.
# [11000/414113] Tokenized the captions.
# [12000/414113] Tokenized the captions.
# [13000/414113] Tokenized the captions.
# [14000/414113] Tokenized the captions.
# [15000/414113] Tokenized the captions.
# [16000/414113] Tokenized the captions.
# [17000/414113] Tokenized the captions.
# [18000/414113] Tokenized the captions.
# [19000/414113] Tokenized the captions.
# [20000/414113] Tokenized the captions.
# [21000/414113] Tokenized the captions.
# [22000/414113] Tokenized the captions.
# [23000/414113] Tokenized the captions.
# [24000/414113] Tokenized the captions.
# [25000/414113] Tokenized the captions.
# [26000/414113] Tokenized the captions.
# [27000/414113] Tokenized the captions.
# [28000/414113] Tokenized the captions.
# [29000/414113] Tokenized the captions.
# [30000/414113] Tokenized the captions.
# [31000/414113] Tokenized the captions.
# [32000/414113] Tokenized the captions.
# [33000/414113] Tokenized the captions.
# [34000/414113] Tokenized the captions.
# [35000/414113] Tokenized the captions.
# [36000/414113] Tokenized the captions.
# [37000/414113] Tokenized the captions.
# [38000/414113] Tokenized the captions.
# [39000/414113] Tokenized the captions.
# [40000/414113] Tokenized the captions.
# [41000/414113] Tokenized the captions.
# [42000/414113] Tokenized the captions.
# [43000/414113] Tokenized the captions.
# [44000/414113] Tokenized the captions.
# [45000/414113] Tokenized the captions.
# [46000/414113] Tokenized the captions.
# [47000/414113] Tokenized the captions.
# [48000/414113] Tokenized the captions.
# [49000/414113] Tokenized the captions.
# [50000/414113] Tokenized the captions.
# [51000/414113] Tokenized the captions.
# [52000/414113] Tokenized the captions.
# [53000/414113] Tokenized the captions.
# [54000/414113] Tokenized the captions.
# [55000/414113] Tokenized the captions.
# [56000/414113] Tokenized the captions.
# [57000/414113] Tokenized the captions.
# [58000/414113] Tokenized the captions.
# [59000/414113] Tokenized the captions.
# [60000/414113] Tokenized the captions.
# [61000/414113] Tokenized the captions.
# [62000/414113] Tokenized the captions.
# [63000/414113] Tokenized the captions.
# [64000/414113] Tokenized the captions.
# [65000/414113] Tokenized the captions.
# [66000/414113] Tokenized the captions.
# [67000/414113] Tokenized the captions.
# [68000/414113] Tokenized the captions.
# [69000/414113] Tokenized the captions.
# [70000/414113] Tokenized the captions.
# [71000/414113] Tokenized the captions.
# [72000/414113] Tokenized the captions.
# [73000/414113] Tokenized the captions.
# [74000/414113] Tokenized the captions.
# [75000/414113] Tokenized the captions.
# [76000/414113] Tokenized the captions.
# [77000/414113] Tokenized the captions.
# [78000/414113] Tokenized the captions.
# [79000/414113] Tokenized the captions.
# [80000/414113] Tokenized the captions.
# [81000/414113] Tokenized the captions.
# [82000/414113] Tokenized the captions.
# [83000/414113] Tokenized the captions.
# [84000/414113] Tokenized the captions.
# [85000/414113] Tokenized the captions.
# [86000/414113] Tokenized the captions.
# [87000/414113] Tokenized the captions.
# [88000/414113] Tokenized the captions.
# [89000/414113] Tokenized the captions.
# [90000/414113] Tokenized the captions.
# [91000/414113] Tokenized the captions.
# [92000/414113] Tokenized the captions.
# [93000/414113] Tokenized the captions.
# [94000/414113] Tokenized the captions.
# [95000/414113] Tokenized the captions.
# [96000/414113] Tokenized the captions.
# [97000/414113] Tokenized the captions.
# [98000/414113] Tokenized the captions.
# [99000/414113] Tokenized the captions.
# [100000/414113] Tokenized the captions.
# [101000/414113] Tokenized the captions.
# [102000/414113] Tokenized the captions.
# [103000/414113] Tokenized the captions.
# [104000/414113] Tokenized the captions.
# [105000/414113] Tokenized the captions.
# [106000/414113] Tokenized the captions.
# [107000/414113] Tokenized the captions.
# [108000/414113] Tokenized the captions.
# [109000/414113] Tokenized the captions.
# [110000/414113] Tokenized the captions.
# [111000/414113] Tokenized the captions.
# [112000/414113] Tokenized the captions.
# [113000/414113] Tokenized the captions.
# [114000/414113] Tokenized the captions.
# [115000/414113] Tokenized the captions.
# [116000/414113] Tokenized the captions.
# [117000/414113] Tokenized the captions.
# [118000/414113] Tokenized the captions.
# [119000/414113] Tokenized the captions.
# [120000/414113] Tokenized the captions.
# [121000/414113] Tokenized the captions.
# [122000/414113] Tokenized the captions.
# [123000/414113] Tokenized the captions.
# [124000/414113] Tokenized the captions.
# [125000/414113] Tokenized the captions.
# [126000/414113] Tokenized the captions.
# [127000/414113] Tokenized the captions.
# [128000/414113] Tokenized the captions.
# [129000/414113] Tokenized the captions.
# [130000/414113] Tokenized the captions.
# [131000/414113] Tokenized the captions.
# [132000/414113] Tokenized the captions.
# [133000/414113] Tokenized the captions.
# [134000/414113] Tokenized the captions.
# [135000/414113] Tokenized the captions.
# [136000/414113] Tokenized the captions.
# [137000/414113] Tokenized the captions.
# [138000/414113] Tokenized the captions.
# [139000/414113] Tokenized the captions.
# [140000/414113] Tokenized the captions.
# [141000/414113] Tokenized the captions.
# [142000/414113] Tokenized the captions.
# [143000/414113] Tokenized the captions.
# [144000/414113] Tokenized the captions.
# [145000/414113] Tokenized the captions.
# [146000/414113] Tokenized the captions.
# [147000/414113] Tokenized the captions.
# [148000/414113] Tokenized the captions.
# [149000/414113] Tokenized the captions.
# [150000/414113] Tokenized the captions.
# [151000/414113] Tokenized the captions.
# [152000/414113] Tokenized the captions.
# [153000/414113] Tokenized the captions.
# [154000/414113] Tokenized the captions.
# [155000/414113] Tokenized the captions.
# [156000/414113] Tokenized the captions.
# [157000/414113] Tokenized the captions.
# [158000/414113] Tokenized the captions.
# [159000/414113] Tokenized the captions.
# [160000/414113] Tokenized the captions.
# [161000/414113] Tokenized the captions.
# [162000/414113] Tokenized the captions.
# [163000/414113] Tokenized the captions.
# [164000/414113] Tokenized the captions.
# [165000/414113] Tokenized the captions.
# [166000/414113] Tokenized the captions.
# [167000/414113] Tokenized the captions.
# [168000/414113] Tokenized the captions.
# [169000/414113] Tokenized the captions.
# [170000/414113] Tokenized the captions.
# [171000/414113] Tokenized the captions.
# [172000/414113] Tokenized the captions.
# [173000/414113] Tokenized the captions.
# [174000/414113] Tokenized the captions.
# [175000/414113] Tokenized the captions.
# [176000/414113] Tokenized the captions.
# [177000/414113] Tokenized the captions.
# [178000/414113] Tokenized the captions.
# [179000/414113] Tokenized the captions.
# [180000/414113] Tokenized the captions.
# [181000/414113] Tokenized the captions.
# [182000/414113] Tokenized the captions.
# [183000/414113] Tokenized the captions.
# [184000/414113] Tokenized the captions.
# [185000/414113] Tokenized the captions.
# [186000/414113] Tokenized the captions.
# [187000/414113] Tokenized the captions.
# [188000/414113] Tokenized the captions.
# [189000/414113] Tokenized the captions.
# [190000/414113] Tokenized the captions.
# [191000/414113] Tokenized the captions.
# [192000/414113] Tokenized the captions.
# [193000/414113] Tokenized the captions.
# [194000/414113] Tokenized the captions.
# [195000/414113] Tokenized the captions.
# [196000/414113] Tokenized the captions.
# [197000/414113] Tokenized the captions.
# [198000/414113] Tokenized the captions.
# [199000/414113] Tokenized the captions.
# [200000/414113] Tokenized the captions.
# [201000/414113] Tokenized the captions.
# [202000/414113] Tokenized the captions.
# [203000/414113] Tokenized the captions.
# [204000/414113] Tokenized the captions.
# [205000/414113] Tokenized the captions.
# [206000/414113] Tokenized the captions.
# [207000/414113] Tokenized the captions.
# [208000/414113] Tokenized the captions.
# [209000/414113] Tokenized the captions.
# [210000/414113] Tokenized the captions.
# [211000/414113] Tokenized the captions.
# [212000/414113] Tokenized the captions.
# [213000/414113] Tokenized the captions.
# [214000/414113] Tokenized the captions.
# [215000/414113] Tokenized the captions.
# [216000/414113] Tokenized the captions.
# [217000/414113] Tokenized the captions.
# [218000/414113] Tokenized the captions.
# [219000/414113] Tokenized the captions.
# [220000/414113] Tokenized the captions.
# [221000/414113] Tokenized the captions.
# [222000/414113] Tokenized the captions.
# [223000/414113] Tokenized the captions.
# [224000/414113] Tokenized the captions.
# [225000/414113] Tokenized the captions.
# [226000/414113] Tokenized the captions.
# [227000/414113] Tokenized the captions.
# [228000/414113] Tokenized the captions.
# [229000/414113] Tokenized the captions.
# [230000/414113] Tokenized the captions.
# [231000/414113] Tokenized the captions.
# [232000/414113] Tokenized the captions.
# [233000/414113] Tokenized the captions.
# [234000/414113] Tokenized the captions.
# [235000/414113] Tokenized the captions.
# [236000/414113] Tokenized the captions.
# [237000/414113] Tokenized the captions.
# [238000/414113] Tokenized the captions.
# [239000/414113] Tokenized the captions.
# [240000/414113] Tokenized the captions.
# [241000/414113] Tokenized the captions.
# [242000/414113] Tokenized the captions.
# [243000/414113] Tokenized the captions.
# [244000/414113] Tokenized the captions.
# [245000/414113] Tokenized the captions.
# [246000/414113] Tokenized the captions.
# [247000/414113] Tokenized the captions.
# [248000/414113] Tokenized the captions.
# [249000/414113] Tokenized the captions.
# [250000/414113] Tokenized the captions.
# [251000/414113] Tokenized the captions.
# [252000/414113] Tokenized the captions.
# [253000/414113] Tokenized the captions.
# [254000/414113] Tokenized the captions.
# [255000/414113] Tokenized the captions.
# [256000/414113] Tokenized the captions.
# [257000/414113] Tokenized the captions.
# [258000/414113] Tokenized the captions.
# [259000/414113] Tokenized the captions.
# [260000/414113] Tokenized the captions.
# [261000/414113] Tokenized the captions.
# [262000/414113] Tokenized the captions.
# [263000/414113] Tokenized the captions.
# [264000/414113] Tokenized the captions.
# [265000/414113] Tokenized the captions.
# [266000/414113] Tokenized the captions.
# [267000/414113] Tokenized the captions.
# [268000/414113] Tokenized the captions.
# [269000/414113] Tokenized the captions.
# [270000/414113] Tokenized the captions.
# [271000/414113] Tokenized the captions.
# [272000/414113] Tokenized the captions.
# [273000/414113] Tokenized the captions.
# [274000/414113] Tokenized the captions.
# [275000/414113] Tokenized the captions.
# [276000/414113] Tokenized the captions.
# [277000/414113] Tokenized the captions.
# [278000/414113] Tokenized the captions.
# [279000/414113] Tokenized the captions.
# [280000/414113] Tokenized the captions.
# [281000/414113] Tokenized the captions.
# [282000/414113] Tokenized the captions.
# [283000/414113] Tokenized the captions.
# [284000/414113] Tokenized the captions.
# [285000/414113] Tokenized the captions.
# [286000/414113] Tokenized the captions.
# [287000/414113] Tokenized the captions.
# [288000/414113] Tokenized the captions.
# [289000/414113] Tokenized the captions.
# [290000/414113] Tokenized the captions.
# [291000/414113] Tokenized the captions.
# [292000/414113] Tokenized the captions.
# [293000/414113] Tokenized the captions.
# [294000/414113] Tokenized the captions.
# [295000/414113] Tokenized the captions.
# [296000/414113] Tokenized the captions.
# [297000/414113] Tokenized the captions.
# [298000/414113] Tokenized the captions.
# [299000/414113] Tokenized the captions.
# [300000/414113] Tokenized the captions.
# [301000/414113] Tokenized the captions.
# [302000/414113] Tokenized the captions.
# [303000/414113] Tokenized the captions.
# [304000/414113] Tokenized the captions.
# [305000/414113] Tokenized the captions.
# [306000/414113] Tokenized the captions.
# [307000/414113] Tokenized the captions.
# [308000/414113] Tokenized the captions.
# [309000/414113] Tokenized the captions.
# [310000/414113] Tokenized the captions.
# [311000/414113] Tokenized the captions.
# [312000/414113] Tokenized the captions.
# [313000/414113] Tokenized the captions.
# [314000/414113] Tokenized the captions.
# [315000/414113] Tokenized the captions.
# [316000/414113] Tokenized the captions.
# [317000/414113] Tokenized the captions.
# [318000/414113] Tokenized the captions.
# [319000/414113] Tokenized the captions.
# [320000/414113] Tokenized the captions.
# [321000/414113] Tokenized the captions.
# [322000/414113] Tokenized the captions.
# [323000/414113] Tokenized the captions.
# [324000/414113] Tokenized the captions.
# [325000/414113] Tokenized the captions.
# [326000/414113] Tokenized the captions.
# [327000/414113] Tokenized the captions.
# [328000/414113] Tokenized the captions.
# [329000/414113] Tokenized the captions.
# [330000/414113] Tokenized the captions.
# [331000/414113] Tokenized the captions.
# [332000/414113] Tokenized the captions.
# [333000/414113] Tokenized the captions.
# [334000/414113] Tokenized the captions.
# [335000/414113] Tokenized the captions.
# [336000/414113] Tokenized the captions.
# [337000/414113] Tokenized the captions.
# [338000/414113] Tokenized the captions.
# [339000/414113] Tokenized the captions.
# [340000/414113] Tokenized the captions.
# [341000/414113] Tokenized the captions.
# [342000/414113] Tokenized the captions.
# [343000/414113] Tokenized the captions.
# [344000/414113] Tokenized the captions.
# [345000/414113] Tokenized the captions.
# [346000/414113] Tokenized the captions.
# [347000/414113] Tokenized the captions.
# [348000/414113] Tokenized the captions.
# [349000/414113] Tokenized the captions.
# [350000/414113] Tokenized the captions.
# [351000/414113] Tokenized the captions.
# [352000/414113] Tokenized the captions.
# [353000/414113] Tokenized the captions.
# [354000/414113] Tokenized the captions.
# [355000/414113] Tokenized the captions.
# [356000/414113] Tokenized the captions.
# [357000/414113] Tokenized the captions.
# [358000/414113] Tokenized the captions.
# [359000/414113] Tokenized the captions.
# [360000/414113] Tokenized the captions.
# [361000/414113] Tokenized the captions.
# [362000/414113] Tokenized the captions.
# [363000/414113] Tokenized the captions.
# [364000/414113] Tokenized the captions.
# [365000/414113] Tokenized the captions.
# [366000/414113] Tokenized the captions.
# [367000/414113] Tokenized the captions.
# [368000/414113] Tokenized the captions.
# [369000/414113] Tokenized the captions.
# [370000/414113] Tokenized the captions.
# [371000/414113] Tokenized the captions.
# [372000/414113] Tokenized the captions.
# [373000/414113] Tokenized the captions.
# [374000/414113] Tokenized the captions.
# [375000/414113] Tokenized the captions.
# [376000/414113] Tokenized the captions.
# [377000/414113] Tokenized the captions.
# [378000/414113] Tokenized the captions.
# [379000/414113] Tokenized the captions.
# [380000/414113] Tokenized the captions.
# [381000/414113] Tokenized the captions.
# [382000/414113] Tokenized the captions.
# [383000/414113] Tokenized the captions.
# [384000/414113] Tokenized the captions.
# [385000/414113] Tokenized the captions.
# [386000/414113] Tokenized the captions.
# [387000/414113] Tokenized the captions.
# [388000/414113] Tokenized the captions.
# [389000/414113] Tokenized the captions.
# [390000/414113] Tokenized the captions.
# [391000/414113] Tokenized the captions.
# [392000/414113] Tokenized the captions.
# [393000/414113] Tokenized the captions.
# [394000/414113] Tokenized the captions.
# [395000/414113] Tokenized the captions.
# [396000/414113] Tokenized the captions.
# [397000/414113] Tokenized the captions.
# [398000/414113] Tokenized the captions.
# [399000/414113] Tokenized the captions.
# [400000/414113] Tokenized the captions.
# [401000/414113] Tokenized the captions.
# [402000/414113] Tokenized the captions.
# [403000/414113] Tokenized the captions.
# [404000/414113] Tokenized the captions.
# [405000/414113] Tokenized the captions.
# [406000/414113] Tokenized the captions.
# [407000/414113] Tokenized the captions.
# [408000/414113] Tokenized the captions.
# [409000/414113] Tokenized the captions.
# [410000/414113] Tokenized the captions.
# [411000/414113] Tokenized the captions.
# [412000/414113] Tokenized the captions.
# [413000/414113] Tokenized the captions.
# [414000/414113] Tokenized the captions.
# Total vocabulary size: 9948
# Saved the vocabulary wrapper to '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/vocabulary.pkl'

# %%
# resize image 256*256
def reshape_image(image, shape):
    """Resize an image to the given shape."""
    return image.resize(shape, Image.ANTIALIAS)
 
def reshape_images(image_path, output_path, shape):
    """Reshape the images in 'image_path' and save into 'output_path'."""
    if not os.path.exists(output_path):
        os.makedirs(output_path)
 
    images = os.listdir(image_path)
    num_im = len(images)
    for i, im in enumerate(images):
        with open(os.path.join(image_path, im), 'r+b') as f:
            with Image.open(f) as image:
                image = reshape_image(image, shape)
                image.save(os.path.join(output_path, im), image.format)
        if (i+1) % 100 == 0:
            print ("[{}/{}] Resized the images and saved into '{}'."
                   .format(i+1, num_im, output_path))

image_path = coco_data+'/train2014/'
output_path = coco_data+'/resized_images/'
image_shape = [256, 256]
reshape_images(image_path, output_path, image_shape)
# Out:
# /tmp/ipykernel_99190/4293304408.py:4: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   return image.resize(shape, Image.ANTIALIAS)
# [100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [1000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [1100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [1200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [1300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [1400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [1500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [1600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [1700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [1800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [1900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [2000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [2100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [2200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [2300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [2400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [2500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [2600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [2700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [2800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [2900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [3000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [3100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [3200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [3300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [3400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [3500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [3600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [3700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [3800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [3900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [4000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [4100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [4200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [4300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [4400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [4500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [4600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [4700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [4800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [4900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [5000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [5100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [5200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [5300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [5400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [5500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [5600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [5700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [5800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [5900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [6000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [6100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [6200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [6300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [6400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [6500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [6600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [6700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [6800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [6900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [7000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [7100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [7200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [7300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [7400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [7500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [7600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [7700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [7800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [7900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [8000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [8100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [8200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [8300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [8400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [8500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [8600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [8700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [8800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [8900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [9000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [9100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [9200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [9300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [9400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [9500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [9600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [9700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [9800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [9900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [10000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [10100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [10200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [10300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [10400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [10500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [10600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [10700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [10800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [10900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [11000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [11100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [11200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [11300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [11400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [11500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [11600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [11700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [11800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [11900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [12000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [12100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [12200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [12300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [12400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [12500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [12600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [12700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [12800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [12900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [13000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [13100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [13200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [13300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [13400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [13500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [13600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [13700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [13800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [13900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [14000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [14100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [14200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [14300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [14400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [14500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [14600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [14700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [14800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [14900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [15000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [15100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [15200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [15300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [15400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [15500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [15600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [15700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [15800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [15900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [16000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [16100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [16200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [16300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [16400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [16500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [16600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [16700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [16800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [16900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [17000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [17100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [17200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [17300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [17400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [17500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [17600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [17700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [17800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [17900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [18000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [18100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [18200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [18300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [18400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [18500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [18600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [18700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [18800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [18900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [19000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [19100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [19200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [19300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [19400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [19500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [19600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [19700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [19800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [19900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [20000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [20100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [20200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [20300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [20400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [20500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [20600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [20700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [20800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [20900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [21000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [21100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [21200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [21300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [21400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [21500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [21600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [21700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [21800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [21900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [22000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [22100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [22200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [22300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [22400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [22500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [22600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [22700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [22800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [22900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [23000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [23100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [23200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [23300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [23400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [23500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [23600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [23700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [23800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [23900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [24000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [24100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [24200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [24300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [24400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [24500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [24600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [24700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [24800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [24900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [25000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [25100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [25200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [25300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [25400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [25500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [25600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [25700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [25800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [25900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [26000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [26100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [26200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [26300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [26400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [26500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [26600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [26700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [26800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [26900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [27000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [27100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [27200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [27300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [27400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [27500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [27600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [27700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [27800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [27900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [28000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [28100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [28200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [28300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [28400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [28500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [28600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [28700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [28800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [28900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [29000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [29100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [29200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [29300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [29400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [29500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [29600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [29700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [29800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [29900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [30000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [30100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [30200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [30300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [30400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [30500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [30600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [30700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [30800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [30900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [31000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [31100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [31200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [31300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [31400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [31500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [31600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [31700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [31800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [31900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [32000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [32100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [32200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [32300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [32400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [32500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [32600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [32700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [32800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [32900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [33000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [33100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [33200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [33300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [33400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [33500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [33600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [33700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [33800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [33900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [34000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [34100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [34200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [34300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [34400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [34500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [34600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [34700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [34800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [34900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [35000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [35100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [35200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [35300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [35400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [35500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [35600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [35700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [35800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [35900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [36000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [36100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [36200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [36300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [36400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [36500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [36600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [36700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [36800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [36900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [37000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [37100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [37200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [37300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [37400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [37500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [37600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [37700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [37800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [37900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [38000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [38100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [38200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [38300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [38400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [38500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [38600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [38700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [38800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [38900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [39000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [39100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [39200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [39300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [39400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [39500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [39600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [39700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [39800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [39900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [40000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [40100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [40200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [40300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [40400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [40500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [40600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [40700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [40800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [40900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [41000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [41100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [41200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# ...
# [69100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [69200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [69300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [69400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [69500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [69600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [69700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [69800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [69900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [70000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [70100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [70200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [70300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [70400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [70500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [70600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [70700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [70800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [70900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [71000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [71100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [71200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [71300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [71400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [71500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [71600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [71700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [71800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [71900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [72000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [72100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [72200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [72300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [72400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [72500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [72600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [72700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [72800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [72900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [73000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [73100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [73200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [73300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [73400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [73500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [73600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [73700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [73800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [73900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [74000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [74100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [74200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [74300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [74400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [74500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [74600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [74700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [74800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [74900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [75000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [75100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [75200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [75300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [75400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [75500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [75600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [75700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [75800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [75900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [76000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [76100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [76200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [76300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [76400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [76500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [76600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [76700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [76800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [76900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [77000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [77100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [77200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [77300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [77400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [77500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [77600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [77700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [77800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [77900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [78000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [78100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [78200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [78300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [78400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [78500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [78600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [78700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [78800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [78900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [79000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [79100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [79200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [79300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [79400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [79500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [79600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [79700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [79800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [79900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [80000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [80100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [80200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [80300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [80400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [80500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [80600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [80700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [80800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [80900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [81000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [81100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [81200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [81300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [81400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [81500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [81600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [81700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [81800/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [81900/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [82000/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [82100/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [82200/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [82300/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [82400/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [82500/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [82600/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.
# [82700/82783] Resized the images and saved into '/media/hyunsu/data2/01.DataAnalysis/data_ML/COCO/resized_images/'.

# %% [markdown]
# ## Data loader
# * 위 셀들은 data preprocess들이다. vocabulary를 준비하고, image size를 resize하는등.
# * ML과정에서는 한번만 하면 되는 code들이다. 이제 밑으로는 model을 test할 때마다 실행해야하는 코드들이다.

# %%
class CustomCocoDataset(data.Dataset):
    """COCO Custom Dataset compatible with torch.utils.data.DataLoader."""
    def __init__(self, data_path, coco_json_path, vocabulary, transform=None):
        """Set the path for images, captions and vocabulary wrapper.
        
        Args:
            root: image directory.
            json: coco annotation file path.
            vocab: vocabulary wrapper.
            transform: image transformer.
        """
        self.root = data_path
        self.coco_data = COCO(coco_json_path)
        self.indices = list(self.coco_data.anns.keys())
        self.vocabulary = vocabulary
        self.transform = transform
 
    def __getitem__(self, idx):
        """Returns one data pair (image and caption)."""
        coco_data = self.coco_data
        vocabulary = self.vocabulary
        annotation_id = self.indices[idx]
        caption = coco_data.anns[annotation_id]['caption']
        image_id = coco_data.anns[annotation_id]['image_id']
        image_path = coco_data.loadImgs(image_id)[0]['file_name']
 
        image = Image.open(os.path.join(self.root, image_path)).convert('RGB')
        if self.transform is not None:
            image = self.transform(image)
 
        # Convert caption (string) to word ids.
        word_tokens = nltk.tokenize.word_tokenize(str(caption).lower())
        caption = []
        caption.append(vocabulary('<start>'))
        caption.extend([vocabulary(token) for token in word_tokens])
        caption.append(vocabulary('<end>'))
        ground_truth = torch.Tensor(caption)
        return image, ground_truth
 
    def __len__(self):
        return len(self.indices)
 
def collate_function(data_batch):
    """Creates mini-batch tensors from the list of tuples (image, caption).
    
    We should build custom collate_fn rather than using default collate_fn, 
    because merging caption (including padding) is not supported in default.
    Args:
        data: list of tuple (image, caption). 
            - image: torch tensor of shape (3, 256, 256).
            - caption: torch tensor of shape (?); variable length.
    Returns:
        images: torch tensor of shape (batch_size, 3, 256, 256).
        targets: torch tensor of shape (batch_size, padded_length).
        lengths: list; valid length for each padded caption.
    """
    # Sort a data list by caption length (descending order).
    data_batch.sort(key=lambda d: len(d[1]), reverse=True)
    imgs, caps = zip(*data_batch)
 
    # Merge images (from list of 3D tensors to 4D tensor).
    # Originally, imgs is a list of <batch_size> number of RGB images with dimensions (3, 256, 256)
    # This line of code turns it into a single tensor of dimensions (<batch_size>, 3, 256, 256)
    imgs = torch.stack(imgs, 0)
 
    # Merge captions (from list of 1D tensors to 2D tensor), similar to merging of images donw above.
    cap_lens = [len(cap) for cap in caps]
    tgts = torch.zeros(len(caps), max(cap_lens)).long()
    for i, cap in enumerate(caps):
        end = cap_lens[i]
        tgts[i, :end] = cap[:end]        
    return imgs, tgts, cap_lens

def get_loader(data_path, coco_json_path, vocabulary, transform, batch_size, shuffle, num_workers):
    """Returns torch.utils.data.DataLoader for custom coco dataset."""
    # COCO caption dataset
    coco_dataser = CustomCocoDataset(data_path=data_path,
                       coco_json_path=coco_json_path,
                       vocabulary=vocabulary,
                       transform=transform)
    
    # Data loader for COCO dataset
    # This will return (images, captions, lengths) for each iteration.
    # images: a tensor of shape (batch_size, 3, 224, 224).
    # captions: a tensor of shape (batch_size, padded_length).
    # lengths: a list indicating valid length for each caption. length is (batch_size).
    custom_data_loader = torch.utils.data.DataLoader(dataset=coco_dataser, 
                                              batch_size=batch_size,
                                              shuffle=shuffle,
                                              num_workers=num_workers,
                                              collate_fn=collate_function)
    return custom_data_loader

# %%
# model definition
class CNNModel(nn.Module):
    def __init__(self, embedding_size):
        """Load the pretrained ResNet-152 and replace top fc layer."""
        super(CNNModel, self).__init__()
        resnet = models.resnet152(pretrained=True)
        module_list = list(resnet.children())[:-1]      # delete the last fc layer.
        self.resnet_module = nn.Sequential(*module_list)
        self.linear_layer = nn.Linear(resnet.fc.in_features, embedding_size)
        self.batch_norm = nn.BatchNorm1d(embedding_size, momentum=0.01)
        
    def forward(self, input_images):
        """Extract feature vectors from input images."""
        with torch.no_grad():
            resnet_features = self.resnet_module(input_images) # don't train resnet
        resnet_features = resnet_features.reshape(resnet_features.size(0), -1)
        final_features = self.batch_norm(self.linear_layer(resnet_features))
        return final_features

class LSTMModel(nn.Module):
    def __init__(self, embedding_size, hidden_layer_size, vocabulary_size, num_layers, max_seq_len=20):
        """Set the hyper-parameters and build the layers."""
        super(LSTMModel, self).__init__()
        self.embedding_layer = nn.Embedding(vocabulary_size, embedding_size)
        self.lstm_layer = nn.LSTM(embedding_size, hidden_layer_size, num_layers, batch_first=True)
        self.linear_layer = nn.Linear(hidden_layer_size, vocabulary_size)
        self.max_seq_len = max_seq_len
        
    def forward(self, input_features, capts, lens):
        """Decode image feature vectors and generates captions."""
        embeddings = self.embedding_layer(capts)
        embeddings = torch.cat((input_features.unsqueeze(1), embeddings), 1)
        lstm_input = pack_padded_sequence(embeddings, lens, batch_first=True) 
        hidden_variables, _ = self.lstm_layer(lstm_input)
        model_outputs = self.linear_layer(hidden_variables[0])
        return model_outputs
    
    def sample(self, input_features, lstm_states=None):
        """Generate captions for given image features using greedy search."""
        sampled_indices = []
        lstm_inputs = input_features.unsqueeze(1)
        for i in range(self.max_seq_len):
            hidden_variables, lstm_states = self.lstm_layer(lstm_inputs, lstm_states)          # hiddens: (batch_size, 1, hidden_size)
            model_outputs = self.linear_layer(hidden_variables.squeeze(1))            # outputs:  (batch_size, vocab_size)
            _, predicted_outputs = model_outputs.max(1)                        # predicted: (batch_size)
            sampled_indices.append(predicted_outputs)
            lstm_inputs = self.embedding_layer(predicted_outputs)                       # inputs: (batch_size, embed_size)
            lstm_inputs = lstm_inputs.unsqueeze(1)                         # inputs: (batch_size, 1, embed_size)
        sampled_indices = torch.stack(sampled_indices, 1)                # sampled_ids: (batch_size, max_seq_length)
        return sampled_indices

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


# Create model directory
if not os.path.exists('models_dir/'):
    os.makedirs('models_dir/')

    
# Image preprocessing, normalization for the pretrained resnet
transform = transforms.Compose([ 
    transforms.RandomCrop(224), # data augmentation by cropping
    transforms.RandomHorizontalFlip(), # dat augmentation by h-flipping
    transforms.ToTensor(), 
    transforms.Normalize((0.485, 0.456, 0.406), 
                         (0.229, 0.224, 0.225))])

# %%
# Load vocabulary wrapper
with open(coco_data+'/vocabulary.pkl', 'rb') as f:
    vocabulary = pickle.load(f)

    
# Build data loader
custom_data_loader = get_loader(coco_data+'/resized_images', coco_data+'/annotations/captions_train2014.json', vocabulary, 
                         transform, 128,
                         shuffle=True, num_workers=2) 


# Build the models
encoder_model = CNNModel(256).to(device)
decoder_model = LSTMModel(256, 512, len(vocabulary), 1).to(device)
 
    
# Loss and optimizer
loss_criterion = nn.CrossEntropyLoss()
parameters = list(decoder_model.parameters()) + list(encoder_model.linear_layer.parameters()) + list(encoder_model.batch_norm.parameters())
optimizer = torch.optim.Adam(parameters, lr=0.001)
# Out:
# loading annotations into memory...
# Done (t=0.94s)
# creating index...
# index created!
# /home/hyunsu/anaconda3/envs/th1p12/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/hyunsu/anaconda3/envs/th1p12/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /home/hyunsu/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
#   0%|          | 0.00/230M [00:00<?, ?B/s]

# %%
# Train the models
total_num_steps = len(custom_data_loader)
for epoch in range(5):
    for i, (imgs, caps, lens) in enumerate(custom_data_loader):
 
        # Set mini-batch dataset
        imgs = imgs.to(device)
        caps = caps.to(device)
        tgts = pack_padded_sequence(caps, lens, batch_first=True)[0]
 
        # Forward, backward and optimize
        feats = encoder_model(imgs)
        outputs = decoder_model(feats, caps, lens)
        loss = loss_criterion(outputs, tgts)
        decoder_model.zero_grad()
        encoder_model.zero_grad()
        loss.backward()
        optimizer.step()
 
        # Print log info
        if i % 10 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Perplexity: {:5.4f}'
                  .format(epoch, 5, i, total_num_steps, loss.item(), np.exp(loss.item()))) 
 
        # Save the model checkpoints
        if (i+1) % 1000 == 0:
            torch.save(decoder_model.state_dict(), os.path.join(
                'models_dir/', 'decoder-{}-{}.ckpt'.format(epoch+1, i+1)))
            torch.save(encoder_model.state_dict(), os.path.join(
                'models_dir/', 'encoder-{}-{}.ckpt'.format(epoch+1, i+1)))
# Out:
# Epoch [0/5], Step [0/3236], Loss: 9.2104, Perplexity: 10000.8692
# Epoch [0/5], Step [10/3236], Loss: 5.8434, Perplexity: 344.9434
# Epoch [0/5], Step [20/3236], Loss: 5.4152, Perplexity: 224.7914
# Epoch [0/5], Step [30/3236], Loss: 4.8546, Perplexity: 128.3303
# Epoch [0/5], Step [40/3236], Loss: 4.6734, Perplexity: 107.0605
# Epoch [0/5], Step [50/3236], Loss: 4.3576, Perplexity: 78.0726
# Epoch [0/5], Step [60/3236], Loss: 4.3847, Perplexity: 80.2138
# Epoch [0/5], Step [70/3236], Loss: 4.0040, Perplexity: 54.8148
# Epoch [0/5], Step [80/3236], Loss: 4.1258, Perplexity: 61.9182
# Epoch [0/5], Step [90/3236], Loss: 3.9015, Perplexity: 49.4759
# Epoch [0/5], Step [100/3236], Loss: 3.8327, Perplexity: 46.1864
# Epoch [0/5], Step [110/3236], Loss: 3.8625, Perplexity: 47.5864
# Epoch [0/5], Step [120/3236], Loss: 3.8160, Perplexity: 45.4236
# Epoch [0/5], Step [130/3236], Loss: 3.6483, Perplexity: 38.4092
# Epoch [0/5], Step [140/3236], Loss: 3.9115, Perplexity: 49.9738
# Epoch [0/5], Step [150/3236], Loss: 3.5238, Perplexity: 33.9121
# Epoch [0/5], Step [160/3236], Loss: 3.5019, Perplexity: 33.1774
# Epoch [0/5], Step [170/3236], Loss: 3.5131, Perplexity: 33.5523
# Epoch [0/5], Step [180/3236], Loss: 3.4553, Perplexity: 31.6676
# Epoch [0/5], Step [190/3236], Loss: 3.3428, Perplexity: 28.2974
# Epoch [0/5], Step [200/3236], Loss: 3.3326, Perplexity: 28.0121
# Epoch [0/5], Step [210/3236], Loss: 3.3034, Perplexity: 27.2040
# Epoch [0/5], Step [220/3236], Loss: 3.2813, Perplexity: 26.6091
# Epoch [0/5], Step [230/3236], Loss: 3.4928, Perplexity: 32.8766
# Epoch [0/5], Step [240/3236], Loss: 3.3162, Perplexity: 27.5542
# Epoch [0/5], Step [250/3236], Loss: 3.1730, Perplexity: 23.8800
# Epoch [0/5], Step [260/3236], Loss: 3.3083, Perplexity: 27.3387
# Epoch [0/5], Step [270/3236], Loss: 3.1385, Perplexity: 23.0692
# Epoch [0/5], Step [280/3236], Loss: 3.2252, Perplexity: 25.1586
# Epoch [0/5], Step [290/3236], Loss: 3.0574, Perplexity: 21.2715
# Epoch [0/5], Step [300/3236], Loss: 3.1088, Perplexity: 22.3952
# Epoch [0/5], Step [310/3236], Loss: 3.0785, Perplexity: 21.7267
# Epoch [0/5], Step [320/3236], Loss: 3.0608, Perplexity: 21.3442
# Epoch [0/5], Step [330/3236], Loss: 3.0854, Perplexity: 21.8765
# Epoch [0/5], Step [340/3236], Loss: 2.9988, Perplexity: 20.0611
# Epoch [0/5], Step [350/3236], Loss: 3.1817, Perplexity: 24.0865
# Epoch [0/5], Step [360/3236], Loss: 2.9879, Perplexity: 19.8448
# Epoch [0/5], Step [370/3236], Loss: 3.0969, Perplexity: 22.1295
# Epoch [0/5], Step [380/3236], Loss: 3.0022, Perplexity: 20.1300
# Epoch [0/5], Step [390/3236], Loss: 3.2603, Perplexity: 26.0575
# Epoch [0/5], Step [400/3236], Loss: 3.0226, Perplexity: 20.5443
# Epoch [0/5], Step [410/3236], Loss: 3.0705, Perplexity: 21.5530
# Epoch [0/5], Step [420/3236], Loss: 2.9640, Perplexity: 19.3750
# Epoch [0/5], Step [430/3236], Loss: 2.9247, Perplexity: 18.6287
# Epoch [0/5], Step [440/3236], Loss: 3.0508, Perplexity: 21.1330
# Epoch [0/5], Step [450/3236], Loss: 2.9683, Perplexity: 19.4584
# Epoch [0/5], Step [460/3236], Loss: 2.8403, Perplexity: 17.1210
# Epoch [0/5], Step [470/3236], Loss: 3.0863, Perplexity: 21.8961
# Epoch [0/5], Step [480/3236], Loss: 2.7787, Perplexity: 16.0984
# Epoch [0/5], Step [490/3236], Loss: 3.0272, Perplexity: 20.6395
# Epoch [0/5], Step [500/3236], Loss: 2.7744, Perplexity: 16.0287
# Epoch [0/5], Step [510/3236], Loss: 2.8149, Perplexity: 16.6915
# Epoch [0/5], Step [520/3236], Loss: 2.8018, Perplexity: 16.4739
# Epoch [0/5], Step [530/3236], Loss: 2.9005, Perplexity: 18.1834
# Epoch [0/5], Step [540/3236], Loss: 2.7718, Perplexity: 15.9874
# Epoch [0/5], Step [550/3236], Loss: 2.9941, Perplexity: 19.9681
# Epoch [0/5], Step [560/3236], Loss: 2.8115, Perplexity: 16.6346
# Epoch [0/5], Step [570/3236], Loss: 2.7563, Perplexity: 15.7422
# Epoch [0/5], Step [580/3236], Loss: 2.6971, Perplexity: 14.8365
# Epoch [0/5], Step [590/3236], Loss: 2.6535, Perplexity: 14.2042
# Epoch [0/5], Step [600/3236], Loss: 2.8282, Perplexity: 16.9158
# Epoch [0/5], Step [610/3236], Loss: 2.8653, Perplexity: 17.5536
# Epoch [0/5], Step [620/3236], Loss: 2.7424, Perplexity: 15.5236
# Epoch [0/5], Step [630/3236], Loss: 2.7636, Perplexity: 15.8573
# Epoch [0/5], Step [640/3236], Loss: 2.8784, Perplexity: 17.7858
# Epoch [0/5], Step [650/3236], Loss: 2.8041, Perplexity: 16.5124
# Epoch [0/5], Step [660/3236], Loss: 2.6288, Perplexity: 13.8571
# Epoch [0/5], Step [670/3236], Loss: 3.0738, Perplexity: 21.6243
# Epoch [0/5], Step [680/3236], Loss: 2.8246, Perplexity: 16.8539
# Epoch [0/5], Step [690/3236], Loss: 2.8960, Perplexity: 18.1014
# Epoch [0/5], Step [700/3236], Loss: 2.6260, Perplexity: 13.8188
# Epoch [0/5], Step [710/3236], Loss: 2.6632, Perplexity: 14.3422
# Epoch [0/5], Step [720/3236], Loss: 2.7864, Perplexity: 16.2228
# Epoch [0/5], Step [730/3236], Loss: 2.8082, Perplexity: 16.5800
# Epoch [0/5], Step [740/3236], Loss: 2.6088, Perplexity: 13.5828
# Epoch [0/5], Step [750/3236], Loss: 2.7664, Perplexity: 15.9016
# Epoch [0/5], Step [760/3236], Loss: 2.5632, Perplexity: 12.9776
# Epoch [0/5], Step [770/3236], Loss: 2.6250, Perplexity: 13.8046
# Epoch [0/5], Step [780/3236], Loss: 2.5875, Perplexity: 13.2964
# Epoch [0/5], Step [790/3236], Loss: 2.7175, Perplexity: 15.1430
# Epoch [0/5], Step [800/3236], Loss: 2.5400, Perplexity: 12.6797
# Epoch [0/5], Step [810/3236], Loss: 2.7885, Perplexity: 16.2564
# Epoch [0/5], Step [820/3236], Loss: 2.6711, Perplexity: 14.4561
# Epoch [0/5], Step [830/3236], Loss: 2.6982, Perplexity: 14.8532
# Epoch [0/5], Step [840/3236], Loss: 2.6034, Perplexity: 13.5094
# Epoch [0/5], Step [850/3236], Loss: 2.5428, Perplexity: 12.7154
# Epoch [0/5], Step [860/3236], Loss: 2.6178, Perplexity: 13.7049
# Epoch [0/5], Step [870/3236], Loss: 2.5661, Perplexity: 13.0147
# Epoch [0/5], Step [880/3236], Loss: 2.5695, Perplexity: 13.0596
# Epoch [0/5], Step [890/3236], Loss: 2.5701, Perplexity: 13.0675
# Epoch [0/5], Step [900/3236], Loss: 2.5482, Perplexity: 12.7843
# Epoch [0/5], Step [910/3236], Loss: 2.7182, Perplexity: 15.1529
# Epoch [0/5], Step [920/3236], Loss: 2.5433, Perplexity: 12.7211
# Epoch [0/5], Step [930/3236], Loss: 2.5609, Perplexity: 12.9471
# Epoch [0/5], Step [940/3236], Loss: 2.4292, Perplexity: 11.3494
# Epoch [0/5], Step [950/3236], Loss: 2.5639, Perplexity: 12.9859
# Epoch [0/5], Step [960/3236], Loss: 2.6522, Perplexity: 14.1857
# Epoch [0/5], Step [970/3236], Loss: 2.6144, Perplexity: 13.6593
# Epoch [0/5], Step [980/3236], Loss: 2.5151, Perplexity: 12.3675
# Epoch [0/5], Step [990/3236], Loss: 2.6075, Perplexity: 13.5648
# Epoch [0/5], Step [1000/3236], Loss: 2.5545, Perplexity: 12.8653
# Epoch [0/5], Step [1010/3236], Loss: 2.6855, Perplexity: 14.6651
# Epoch [0/5], Step [1020/3236], Loss: 2.6022, Perplexity: 13.4935
# Epoch [0/5], Step [1030/3236], Loss: 2.5451, Perplexity: 12.7444
# Epoch [0/5], Step [1040/3236], Loss: 2.5880, Perplexity: 13.3031
# Epoch [0/5], Step [1050/3236], Loss: 2.4201, Perplexity: 11.2472
# Epoch [0/5], Step [1060/3236], Loss: 2.4984, Perplexity: 12.1636
# Epoch [0/5], Step [1070/3236], Loss: 2.5166, Perplexity: 12.3866
# Epoch [0/5], Step [1080/3236], Loss: 2.4740, Perplexity: 11.8699
# Epoch [0/5], Step [1090/3236], Loss: 2.5681, Perplexity: 13.0413
# Epoch [0/5], Step [1100/3236], Loss: 2.4915, Perplexity: 12.0795
# Epoch [0/5], Step [1110/3236], Loss: 2.5051, Perplexity: 12.2442
# Epoch [0/5], Step [1120/3236], Loss: 2.4874, Perplexity: 12.0302
# Epoch [0/5], Step [1130/3236], Loss: 2.4054, Perplexity: 11.0824
# Epoch [0/5], Step [1140/3236], Loss: 2.6131, Perplexity: 13.6408
# Epoch [0/5], Step [1150/3236], Loss: 2.5946, Perplexity: 13.3910
# Epoch [0/5], Step [1160/3236], Loss: 2.6270, Perplexity: 13.8322
# Epoch [0/5], Step [1170/3236], Loss: 2.5317, Perplexity: 12.5754
# Epoch [0/5], Step [1180/3236], Loss: 2.4818, Perplexity: 11.9623
# Epoch [0/5], Step [1190/3236], Loss: 2.4200, Perplexity: 11.2457
# Epoch [0/5], Step [1200/3236], Loss: 2.5019, Perplexity: 12.2056
# Epoch [0/5], Step [1210/3236], Loss: 2.5197, Perplexity: 12.4248
# Epoch [0/5], Step [1220/3236], Loss: 2.5260, Perplexity: 12.5029
# Epoch [0/5], Step [1230/3236], Loss: 2.3821, Perplexity: 10.8281
# Epoch [0/5], Step [1240/3236], Loss: 2.5184, Perplexity: 12.4082
# Epoch [0/5], Step [1250/3236], Loss: 2.4909, Perplexity: 12.0721
# Epoch [0/5], Step [1260/3236], Loss: 2.6208, Perplexity: 13.7471
# Epoch [0/5], Step [1270/3236], Loss: 2.5938, Perplexity: 13.3806
# Epoch [0/5], Step [1280/3236], Loss: 2.5290, Perplexity: 12.5405
# Epoch [0/5], Step [1290/3236], Loss: 2.5049, Perplexity: 12.2426
# Epoch [0/5], Step [1300/3236], Loss: 2.4969, Perplexity: 12.1443
# Epoch [0/5], Step [1310/3236], Loss: 2.4955, Perplexity: 12.1283
# Epoch [0/5], Step [1320/3236], Loss: 2.5688, Perplexity: 13.0496
# Epoch [0/5], Step [1330/3236], Loss: 2.4604, Perplexity: 11.7099
# Epoch [0/5], Step [1340/3236], Loss: 2.5008, Perplexity: 12.1926
# Epoch [0/5], Step [1350/3236], Loss: 2.4573, Perplexity: 11.6734
# Epoch [0/5], Step [1360/3236], Loss: 2.3454, Perplexity: 10.4370
# Epoch [0/5], Step [1370/3236], Loss: 2.4585, Perplexity: 11.6877
# Epoch [0/5], Step [1380/3236], Loss: 2.4797, Perplexity: 11.9374
# Epoch [0/5], Step [1390/3236], Loss: 2.5039, Perplexity: 12.2306
# Epoch [0/5], Step [1400/3236], Loss: 2.3369, Perplexity: 10.3491
# Epoch [0/5], Step [1410/3236], Loss: 2.4423, Perplexity: 11.4993
# Epoch [0/5], Step [1420/3236], Loss: 2.4402, Perplexity: 11.4757
# Epoch [0/5], Step [1430/3236], Loss: 2.4277, Perplexity: 11.3329
# Epoch [0/5], Step [1440/3236], Loss: 2.2482, Perplexity: 9.4711
# Epoch [0/5], Step [1450/3236], Loss: 2.3766, Perplexity: 10.7683
# Epoch [0/5], Step [1460/3236], Loss: 2.4367, Perplexity: 11.4348
# Epoch [0/5], Step [1470/3236], Loss: 2.4058, Perplexity: 11.0869
# Epoch [0/5], Step [1480/3236], Loss: 2.3749, Perplexity: 10.7495
# Epoch [0/5], Step [1490/3236], Loss: 2.3857, Perplexity: 10.8665
# Epoch [0/5], Step [1500/3236], Loss: 2.4608, Perplexity: 11.7138
# Epoch [0/5], Step [1510/3236], Loss: 2.4851, Perplexity: 12.0019
# Epoch [0/5], Step [1520/3236], Loss: 2.4984, Perplexity: 12.1625
# Epoch [0/5], Step [1530/3236], Loss: 2.5135, Perplexity: 12.3485
# Epoch [0/5], Step [1540/3236], Loss: 2.3717, Perplexity: 10.7157
# Epoch [0/5], Step [1550/3236], Loss: 2.4934, Perplexity: 12.1023
# Epoch [0/5], Step [1560/3236], Loss: 2.5896, Perplexity: 13.3249
# Epoch [0/5], Step [1570/3236], Loss: 2.4295, Perplexity: 11.3528
# Epoch [0/5], Step [1580/3236], Loss: 2.4775, Perplexity: 11.9119
# Epoch [0/5], Step [1590/3236], Loss: 2.4840, Perplexity: 11.9891
# Epoch [0/5], Step [1600/3236], Loss: 2.4715, Perplexity: 11.8406
# Epoch [0/5], Step [1610/3236], Loss: 2.3542, Perplexity: 10.5296
# Epoch [0/5], Step [1620/3236], Loss: 2.4129, Perplexity: 11.1668
# Epoch [0/5], Step [1630/3236], Loss: 2.4548, Perplexity: 11.6447
# Epoch [0/5], Step [1640/3236], Loss: 2.4738, Perplexity: 11.8672
# Epoch [0/5], Step [1650/3236], Loss: 2.4447, Perplexity: 11.5271
# Epoch [0/5], Step [1660/3236], Loss: 2.3312, Perplexity: 10.2902
# Epoch [0/5], Step [1670/3236], Loss: 2.4883, Perplexity: 12.0405
# Epoch [0/5], Step [1680/3236], Loss: 2.3503, Perplexity: 10.4887
# Epoch [0/5], Step [1690/3236], Loss: 2.3723, Perplexity: 10.7219
# Epoch [0/5], Step [1700/3236], Loss: 2.3926, Perplexity: 10.9417
# Epoch [0/5], Step [1710/3236], Loss: 2.4105, Perplexity: 11.1398
# Epoch [0/5], Step [1720/3236], Loss: 2.5531, Perplexity: 12.8463
# Epoch [0/5], Step [1730/3236], Loss: 2.4772, Perplexity: 11.9074
# Epoch [0/5], Step [1740/3236], Loss: 2.3977, Perplexity: 10.9979
# Epoch [0/5], Step [1750/3236], Loss: 2.3410, Perplexity: 10.3916
# Epoch [0/5], Step [1760/3236], Loss: 2.3653, Perplexity: 10.6474
# Epoch [0/5], Step [1770/3236], Loss: 2.2881, Perplexity: 9.8561
# Epoch [0/5], Step [1780/3236], Loss: 2.4539, Perplexity: 11.6333
# Epoch [0/5], Step [1790/3236], Loss: 2.3882, Perplexity: 10.8937
# Epoch [0/5], Step [1800/3236], Loss: 2.4899, Perplexity: 12.0597
# Epoch [0/5], Step [1810/3236], Loss: 2.3627, Perplexity: 10.6194
# Epoch [0/5], Step [1820/3236], Loss: 2.2514, Perplexity: 9.5012
# Epoch [0/5], Step [1830/3236], Loss: 2.3683, Perplexity: 10.6788
# Epoch [0/5], Step [1840/3236], Loss: 2.3224, Perplexity: 10.2002
# Epoch [0/5], Step [1850/3236], Loss: 2.3752, Perplexity: 10.7530
# Epoch [0/5], Step [1860/3236], Loss: 2.5369, Perplexity: 12.6410
# Epoch [0/5], Step [1870/3236], Loss: 2.5176, Perplexity: 12.3991
# Epoch [0/5], Step [1880/3236], Loss: 2.3678, Perplexity: 10.6739
# Epoch [0/5], Step [1890/3236], Loss: 2.2236, Perplexity: 9.2404
# Epoch [0/5], Step [1900/3236], Loss: 2.2459, Perplexity: 9.4490
# Epoch [0/5], Step [1910/3236], Loss: 2.2985, Perplexity: 9.9591
# Epoch [0/5], Step [1920/3236], Loss: 2.4456, Perplexity: 11.5378
# Epoch [0/5], Step [1930/3236], Loss: 2.2482, Perplexity: 9.4711
# Epoch [0/5], Step [1940/3236], Loss: 2.3745, Perplexity: 10.7456
# Epoch [0/5], Step [1950/3236], Loss: 2.4280, Perplexity: 11.3360
# Epoch [0/5], Step [1960/3236], Loss: 2.4385, Perplexity: 11.4560
# Epoch [0/5], Step [1970/3236], Loss: 2.5535, Perplexity: 12.8520
# Epoch [0/5], Step [1980/3236], Loss: 2.4176, Perplexity: 11.2193
# Epoch [0/5], Step [1990/3236], Loss: 2.4333, Perplexity: 11.3960
# Epoch [0/5], Step [2000/3236], Loss: 2.2330, Perplexity: 9.3279
# Epoch [0/5], Step [2010/3236], Loss: 2.4250, Perplexity: 11.3024
# Epoch [0/5], Step [2020/3236], Loss: 2.3371, Perplexity: 10.3514
# Epoch [0/5], Step [2030/3236], Loss: 2.3032, Perplexity: 10.0061
# Epoch [0/5], Step [2040/3236], Loss: 2.3977, Perplexity: 10.9974
# Epoch [0/5], Step [2050/3236], Loss: 2.4156, Perplexity: 11.1963
# Epoch [0/5], Step [2060/3236], Loss: 2.4452, Perplexity: 11.5332
# Epoch [0/5], Step [2070/3236], Loss: 2.3987, Perplexity: 11.0094
# Epoch [0/5], Step [2080/3236], Loss: 2.3398, Perplexity: 10.3788
# Epoch [0/5], Step [2090/3236], Loss: 2.1887, Perplexity: 8.9235
# Epoch [0/5], Step [2100/3236], Loss: 2.3220, Perplexity: 10.1965
# Epoch [0/5], Step [2110/3236], Loss: 2.2643, Perplexity: 9.6240
# Epoch [0/5], Step [2120/3236], Loss: 2.3087, Perplexity: 10.0609
# Epoch [0/5], Step [2130/3236], Loss: 2.2609, Perplexity: 9.5918
# Epoch [0/5], Step [2140/3236], Loss: 2.3879, Perplexity: 10.8905
# Epoch [0/5], Step [2150/3236], Loss: 2.3150, Perplexity: 10.1248
# Epoch [0/5], Step [2160/3236], Loss: 2.4160, Perplexity: 11.2011
# Epoch [0/5], Step [2170/3236], Loss: 2.4544, Perplexity: 11.6390
# Epoch [0/5], Step [2180/3236], Loss: 2.3690, Perplexity: 10.6871
# Epoch [0/5], Step [2190/3236], Loss: 2.3485, Perplexity: 10.4698
# Epoch [0/5], Step [2200/3236], Loss: 2.2712, Perplexity: 9.6910
# Epoch [0/5], Step [2210/3236], Loss: 2.2584, Perplexity: 9.5675
# Epoch [0/5], Step [2220/3236], Loss: 2.2520, Perplexity: 9.5067
# Epoch [0/5], Step [2230/3236], Loss: 2.3260, Perplexity: 10.2365
# Epoch [0/5], Step [2240/3236], Loss: 2.3802, Perplexity: 10.8074
# Epoch [0/5], Step [2250/3236], Loss: 2.3367, Perplexity: 10.3474
# Epoch [0/5], Step [2260/3236], Loss: 2.3681, Perplexity: 10.6766
# Epoch [0/5], Step [2270/3236], Loss: 2.4668, Perplexity: 11.7852
# Epoch [0/5], Step [2280/3236], Loss: 2.3691, Perplexity: 10.6875
# Epoch [0/5], Step [2290/3236], Loss: 2.2855, Perplexity: 9.8308
# Epoch [0/5], Step [2300/3236], Loss: 2.3134, Perplexity: 10.1087
# Epoch [0/5], Step [2310/3236], Loss: 2.3249, Perplexity: 10.2253
# Epoch [0/5], Step [2320/3236], Loss: 2.1635, Perplexity: 8.7013
# Epoch [0/5], Step [2330/3236], Loss: 2.2800, Perplexity: 9.7765
# Epoch [0/5], Step [2340/3236], Loss: 2.3436, Perplexity: 10.4187
# Epoch [0/5], Step [2350/3236], Loss: 2.3711, Perplexity: 10.7093
# Epoch [0/5], Step [2360/3236], Loss: 2.4277, Perplexity: 11.3333
# Epoch [0/5], Step [2370/3236], Loss: 2.2675, Perplexity: 9.6552
# Epoch [0/5], Step [2380/3236], Loss: 2.2069, Perplexity: 9.0874
# Epoch [0/5], Step [2390/3236], Loss: 2.2730, Perplexity: 9.7082
# Epoch [0/5], Step [2400/3236], Loss: 2.2351, Perplexity: 9.3472
# Epoch [0/5], Step [2410/3236], Loss: 2.2756, Perplexity: 9.7339
# Epoch [0/5], Step [2420/3236], Loss: 2.4275, Perplexity: 11.3307
# Epoch [0/5], Step [2430/3236], Loss: 2.3892, Perplexity: 10.9046
# Epoch [0/5], Step [2440/3236], Loss: 2.3765, Perplexity: 10.7675
# Epoch [0/5], Step [2450/3236], Loss: 2.3258, Perplexity: 10.2353
# Epoch [0/5], Step [2460/3236], Loss: 2.3265, Perplexity: 10.2422
# Epoch [0/5], Step [2470/3236], Loss: 2.4723, Perplexity: 11.8493
# Epoch [0/5], Step [2480/3236], Loss: 2.1932, Perplexity: 8.9642
# Epoch [0/5], Step [2490/3236], Loss: 2.2700, Perplexity: 9.6797
# Epoch [0/5], Step [2500/3236], Loss: 2.3378, Perplexity: 10.3579
# Epoch [0/5], Step [2510/3236], Loss: 2.3743, Perplexity: 10.7438
# Epoch [0/5], Step [2520/3236], Loss: 2.3958, Perplexity: 10.9774
# Epoch [0/5], Step [2530/3236], Loss: 2.2426, Perplexity: 9.4176
# Epoch [0/5], Step [2540/3236], Loss: 2.4507, Perplexity: 11.5969
# Epoch [0/5], Step [2550/3236], Loss: 2.3991, Perplexity: 11.0133
# Epoch [0/5], Step [2560/3236], Loss: 2.4389, Perplexity: 11.4600
# Epoch [0/5], Step [2570/3236], Loss: 2.2238, Perplexity: 9.2423
# Epoch [0/5], Step [2580/3236], Loss: 2.3124, Perplexity: 10.0987
# Epoch [0/5], Step [2590/3236], Loss: 2.2783, Perplexity: 9.7598
# Epoch [0/5], Step [2600/3236], Loss: 2.3178, Perplexity: 10.1529
# Epoch [0/5], Step [2610/3236], Loss: 2.2824, Perplexity: 9.8005
# Epoch [0/5], Step [2620/3236], Loss: 2.2803, Perplexity: 9.7794
# Epoch [0/5], Step [2630/3236], Loss: 2.3105, Perplexity: 10.0795
# Epoch [0/5], Step [2640/3236], Loss: 2.1842, Perplexity: 8.8838
# Epoch [0/5], Step [2650/3236], Loss: 2.0762, Perplexity: 7.9745
# Epoch [0/5], Step [2660/3236], Loss: 2.2539, Perplexity: 9.5248
# Epoch [0/5], Step [2670/3236], Loss: 2.3050, Perplexity: 10.0238
# Epoch [0/5], Step [2680/3236], Loss: 2.2223, Perplexity: 9.2281
# Epoch [0/5], Step [2690/3236], Loss: 2.3552, Perplexity: 10.5398
# Epoch [0/5], Step [2700/3236], Loss: 2.1496, Perplexity: 8.5817
# Epoch [0/5], Step [2710/3236], Loss: 2.3532, Perplexity: 10.5188
# Epoch [0/5], Step [2720/3236], Loss: 2.2091, Perplexity: 9.1078
# Epoch [0/5], Step [2730/3236], Loss: 2.2185, Perplexity: 9.1931
# Epoch [0/5], Step [2740/3236], Loss: 2.2237, Perplexity: 9.2416
# Epoch [0/5], Step [2750/3236], Loss: 2.2145, Perplexity: 9.1571
# Epoch [0/5], Step [2760/3236], Loss: 2.1974, Perplexity: 9.0012
# Epoch [0/5], Step [2770/3236], Loss: 2.3143, Perplexity: 10.1179
# Epoch [0/5], Step [2780/3236], Loss: 2.3666, Perplexity: 10.6616
# Epoch [0/5], Step [2790/3236], Loss: 2.1447, Perplexity: 8.5395
# Epoch [0/5], Step [2800/3236], Loss: 2.2924, Perplexity: 9.8983
# Epoch [0/5], Step [2810/3236], Loss: 2.1386, Perplexity: 8.4875
# Epoch [0/5], Step [2820/3236], Loss: 2.3173, Perplexity: 10.1484
# Epoch [0/5], Step [2830/3236], Loss: 2.2553, Perplexity: 9.5383
# Epoch [0/5], Step [2840/3236], Loss: 2.2087, Perplexity: 9.1036
# Epoch [0/5], Step [2850/3236], Loss: 2.2587, Perplexity: 9.5706
# Epoch [0/5], Step [2860/3236], Loss: 2.3651, Perplexity: 10.6450
# Epoch [0/5], Step [2870/3236], Loss: 2.3119, Perplexity: 10.0940
# Epoch [0/5], Step [2880/3236], Loss: 2.3828, Perplexity: 10.8353
# Epoch [0/5], Step [2890/3236], Loss: 2.2986, Perplexity: 9.9597
# Epoch [0/5], Step [2900/3236], Loss: 2.2793, Perplexity: 9.7702
# Epoch [0/5], Step [2910/3236], Loss: 2.2449, Perplexity: 9.4395
# Epoch [0/5], Step [2920/3236], Loss: 2.4213, Perplexity: 11.2601
# Epoch [0/5], Step [2930/3236], Loss: 2.2584, Perplexity: 9.5675
# Epoch [0/5], Step [2940/3236], Loss: 2.3557, Perplexity: 10.5459
# Epoch [0/5], Step [2950/3236], Loss: 2.1819, Perplexity: 8.8633
# Epoch [0/5], Step [2960/3236], Loss: 2.1577, Perplexity: 8.6510
# Epoch [0/5], Step [2970/3236], Loss: 2.1673, Perplexity: 8.7346
# Epoch [0/5], Step [2980/3236], Loss: 2.2597, Perplexity: 9.5799
# Epoch [0/5], Step [2990/3236], Loss: 2.2026, Perplexity: 9.0483
# Epoch [0/5], Step [3000/3236], Loss: 2.3172, Perplexity: 10.1474
# Epoch [0/5], Step [3010/3236], Loss: 2.3195, Perplexity: 10.1705
# Epoch [0/5], Step [3020/3236], Loss: 2.4000, Perplexity: 11.0235
# Epoch [0/5], Step [3030/3236], Loss: 2.2718, Perplexity: 9.6968
# Epoch [0/5], Step [3040/3236], Loss: 2.2556, Perplexity: 9.5407
# Epoch [0/5], Step [3050/3236], Loss: 2.2711, Perplexity: 9.6905
# Epoch [0/5], Step [3060/3236], Loss: 2.1761, Perplexity: 8.8122
# Epoch [0/5], Step [3070/3236], Loss: 2.3074, Perplexity: 10.0481
# Epoch [0/5], Step [3080/3236], Loss: 2.1293, Perplexity: 8.4091
# Epoch [0/5], Step [3090/3236], Loss: 2.1055, Perplexity: 8.2110
# Epoch [0/5], Step [3100/3236], Loss: 2.3195, Perplexity: 10.1703
# Epoch [0/5], Step [3110/3236], Loss: 2.2416, Perplexity: 9.4080
# Epoch [0/5], Step [3120/3236], Loss: 2.2085, Perplexity: 9.1017
# Epoch [0/5], Step [3130/3236], Loss: 2.2884, Perplexity: 9.8595
# Epoch [0/5], Step [3140/3236], Loss: 2.2681, Perplexity: 9.6606
# Epoch [0/5], Step [3150/3236], Loss: 2.3032, Perplexity: 10.0063
# Epoch [0/5], Step [3160/3236], Loss: 2.1566, Perplexity: 8.6417
# Epoch [0/5], Step [3170/3236], Loss: 2.1620, Perplexity: 8.6888
# Epoch [0/5], Step [3180/3236], Loss: 2.3015, Perplexity: 9.9894
# Epoch [0/5], Step [3190/3236], Loss: 2.2070, Perplexity: 9.0886
# Epoch [0/5], Step [3200/3236], Loss: 2.2983, Perplexity: 9.9576
# Epoch [0/5], Step [3210/3236], Loss: 2.2785, Perplexity: 9.7622
# Epoch [0/5], Step [3220/3236], Loss: 2.2809, Perplexity: 9.7853
# Epoch [0/5], Step [3230/3236], Loss: 2.2361, Perplexity: 9.3568
# Epoch [1/5], Step [0/3236], Loss: 2.1679, Perplexity: 8.7398
# Epoch [1/5], Step [10/3236], Loss: 2.1878, Perplexity: 8.9154
# Epoch [1/5], Step [20/3236], Loss: 2.1793, Perplexity: 8.8397
# Epoch [1/5], Step [30/3236], Loss: 2.1115, Perplexity: 8.2605
# Epoch [1/5], Step [40/3236], Loss: 2.2113, Perplexity: 9.1275
# Epoch [1/5], Step [50/3236], Loss: 2.1520, Perplexity: 8.6021
# Epoch [1/5], Step [60/3236], Loss: 2.1741, Perplexity: 8.7940
# Epoch [1/5], Step [70/3236], Loss: 2.0696, Perplexity: 7.9220
# Epoch [1/5], Step [80/3236], Loss: 2.1971, Perplexity: 8.9991
# Epoch [1/5], Step [90/3236], Loss: 2.3023, Perplexity: 9.9967
# Epoch [1/5], Step [100/3236], Loss: 2.1441, Perplexity: 8.5344
# Epoch [1/5], Step [110/3236], Loss: 2.1637, Perplexity: 8.7037
# Epoch [1/5], Step [120/3236], Loss: 2.2049, Perplexity: 9.0692
# Epoch [1/5], Step [130/3236], Loss: 2.2424, Perplexity: 9.4158
# Epoch [1/5], Step [140/3236], Loss: 2.1885, Perplexity: 8.9222
# Epoch [1/5], Step [150/3236], Loss: 2.0614, Perplexity: 7.8571
# Epoch [1/5], Step [160/3236], Loss: 2.0067, Perplexity: 7.4388
# Epoch [1/5], Step [170/3236], Loss: 2.0537, Perplexity: 7.7964
# Epoch [1/5], Step [180/3236], Loss: 2.1674, Perplexity: 8.7357
# Epoch [1/5], Step [190/3236], Loss: 2.2154, Perplexity: 9.1650
# Epoch [1/5], Step [200/3236], Loss: 2.1141, Perplexity: 8.2822
# Epoch [1/5], Step [210/3236], Loss: 2.1288, Perplexity: 8.4051
# Epoch [1/5], Step [220/3236], Loss: 2.1838, Perplexity: 8.8804
# Epoch [1/5], Step [230/3236], Loss: 2.2580, Perplexity: 9.5635
# Epoch [1/5], Step [240/3236], Loss: 2.3505, Perplexity: 10.4905
# Epoch [1/5], Step [250/3236], Loss: 2.2677, Perplexity: 9.6571
# Epoch [1/5], Step [260/3236], Loss: 2.1258, Perplexity: 8.3795
# Epoch [1/5], Step [270/3236], Loss: 2.2316, Perplexity: 9.3150
# Epoch [1/5], Step [280/3236], Loss: 2.1952, Perplexity: 8.9816
# Epoch [1/5], Step [290/3236], Loss: 2.1704, Perplexity: 8.7620
# Epoch [1/5], Step [300/3236], Loss: 2.0363, Perplexity: 7.6620
# Epoch [1/5], Step [310/3236], Loss: 2.2114, Perplexity: 9.1287
# Epoch [1/5], Step [320/3236], Loss: 2.2420, Perplexity: 9.4117
# Epoch [1/5], Step [330/3236], Loss: 2.2490, Perplexity: 9.4779
# Epoch [1/5], Step [340/3236], Loss: 2.1100, Perplexity: 8.2486
# Epoch [1/5], Step [350/3236], Loss: 2.1493, Perplexity: 8.5790
# Epoch [1/5], Step [360/3236], Loss: 2.0600, Perplexity: 7.8463
# Epoch [1/5], Step [370/3236], Loss: 2.1335, Perplexity: 8.4445
# Epoch [1/5], Step [380/3236], Loss: 2.2898, Perplexity: 9.8732
# Epoch [1/5], Step [390/3236], Loss: 2.1939, Perplexity: 8.9704
# Epoch [1/5], Step [400/3236], Loss: 2.0745, Perplexity: 7.9603
# Epoch [1/5], Step [410/3236], Loss: 2.2471, Perplexity: 9.4605
# Epoch [1/5], Step [420/3236], Loss: 2.1293, Perplexity: 8.4090
# Epoch [1/5], Step [430/3236], Loss: 2.1718, Perplexity: 8.7737
# Epoch [1/5], Step [440/3236], Loss: 2.1614, Perplexity: 8.6832
# Epoch [1/5], Step [450/3236], Loss: 2.1545, Perplexity: 8.6240
# Epoch [1/5], Step [460/3236], Loss: 2.1195, Perplexity: 8.3270
# Epoch [1/5], Step [470/3236], Loss: 2.0304, Perplexity: 7.6171
# Epoch [1/5], Step [480/3236], Loss: 2.2071, Perplexity: 9.0895
# Epoch [1/5], Step [490/3236], Loss: 2.0533, Perplexity: 7.7939
# Epoch [1/5], Step [500/3236], Loss: 2.1373, Perplexity: 8.4762
# Epoch [1/5], Step [510/3236], Loss: 2.2218, Perplexity: 9.2242
# Epoch [1/5], Step [520/3236], Loss: 2.2371, Perplexity: 9.3664
# Epoch [1/5], Step [530/3236], Loss: 2.0856, Perplexity: 8.0492
# Epoch [1/5], Step [540/3236], Loss: 2.1160, Perplexity: 8.2976
# Epoch [1/5], Step [550/3236], Loss: 2.2086, Perplexity: 9.1034
# Epoch [1/5], Step [560/3236], Loss: 2.2098, Perplexity: 9.1135
# Epoch [1/5], Step [570/3236], Loss: 2.1386, Perplexity: 8.4878
# Epoch [1/5], Step [580/3236], Loss: 2.1199, Perplexity: 8.3305
# Epoch [1/5], Step [590/3236], Loss: 2.1958, Perplexity: 8.9872
# Epoch [1/5], Step [600/3236], Loss: 2.1082, Perplexity: 8.2338
# Epoch [1/5], Step [610/3236], Loss: 2.1438, Perplexity: 8.5314
# Epoch [1/5], Step [620/3236], Loss: 2.1312, Perplexity: 8.4251
# Epoch [1/5], Step [630/3236], Loss: 2.2829, Perplexity: 9.8047
# Epoch [1/5], Step [640/3236], Loss: 2.2346, Perplexity: 9.3424
# Epoch [1/5], Step [650/3236], Loss: 2.1951, Perplexity: 8.9806
# Epoch [1/5], Step [660/3236], Loss: 2.1760, Perplexity: 8.8108
# Epoch [1/5], Step [670/3236], Loss: 2.1635, Perplexity: 8.7014
# Epoch [1/5], Step [680/3236], Loss: 2.0437, Perplexity: 7.7194
# Epoch [1/5], Step [690/3236], Loss: 2.0691, Perplexity: 7.9180
# Epoch [1/5], Step [700/3236], Loss: 2.0986, Perplexity: 8.1548
# Epoch [1/5], Step [710/3236], Loss: 2.2204, Perplexity: 9.2113
# Epoch [1/5], Step [720/3236], Loss: 2.1073, Perplexity: 8.2260
# Epoch [1/5], Step [730/3236], Loss: 2.0441, Perplexity: 7.7221
# Epoch [1/5], Step [740/3236], Loss: 2.1074, Perplexity: 8.2269
# Epoch [1/5], Step [750/3236], Loss: 2.1621, Perplexity: 8.6891
# Epoch [1/5], Step [760/3236], Loss: 2.2305, Perplexity: 9.3043
# Epoch [1/5], Step [770/3236], Loss: 2.2129, Perplexity: 9.1423
# Epoch [1/5], Step [780/3236], Loss: 2.2154, Perplexity: 9.1650
# Epoch [1/5], Step [790/3236], Loss: 2.1721, Perplexity: 8.7765
# Epoch [1/5], Step [800/3236], Loss: 2.2615, Perplexity: 9.5970
# Epoch [1/5], Step [810/3236], Loss: 2.2118, Perplexity: 9.1323
# Epoch [1/5], Step [820/3236], Loss: 2.1053, Perplexity: 8.2098
# Epoch [1/5], Step [830/3236], Loss: 2.1521, Perplexity: 8.6033
# Epoch [1/5], Step [840/3236], Loss: 2.2808, Perplexity: 9.7842
# Epoch [1/5], Step [850/3236], Loss: 2.1403, Perplexity: 8.5022
# Epoch [1/5], Step [860/3236], Loss: 2.1628, Perplexity: 8.6956
# Epoch [1/5], Step [870/3236], Loss: 2.1745, Perplexity: 8.7978
# Epoch [1/5], Step [880/3236], Loss: 2.1609, Perplexity: 8.6786
# Epoch [1/5], Step [890/3236], Loss: 2.2426, Perplexity: 9.4175
# Epoch [1/5], Step [900/3236], Loss: 2.1907, Perplexity: 8.9411
# Epoch [1/5], Step [910/3236], Loss: 2.2453, Perplexity: 9.4430
# Epoch [1/5], Step [920/3236], Loss: 2.1169, Perplexity: 8.3052
# Epoch [1/5], Step [930/3236], Loss: 2.0728, Perplexity: 7.9472
# Epoch [1/5], Step [940/3236], Loss: 2.1961, Perplexity: 8.9900
# Epoch [1/5], Step [950/3236], Loss: 2.0637, Perplexity: 7.8754
# Epoch [1/5], Step [960/3236], Loss: 2.2397, Perplexity: 9.3901
# Epoch [1/5], Step [970/3236], Loss: 2.1096, Perplexity: 8.2453
# Epoch [1/5], Step [980/3236], Loss: 2.3102, Perplexity: 10.0760
# Epoch [1/5], Step [990/3236], Loss: 2.1733, Perplexity: 8.7872
# Epoch [1/5], Step [1000/3236], Loss: 2.0864, Perplexity: 8.0563
# Epoch [1/5], Step [1010/3236], Loss: 2.2144, Perplexity: 9.1559
# Epoch [1/5], Step [1020/3236], Loss: 2.3001, Perplexity: 9.9752
# Epoch [1/5], Step [1030/3236], Loss: 2.2452, Perplexity: 9.4419
# Epoch [1/5], Step [1040/3236], Loss: 2.0811, Perplexity: 8.0130
# Epoch [1/5], Step [1050/3236], Loss: 2.0933, Perplexity: 8.1115
# Epoch [1/5], Step [1060/3236], Loss: 2.2579, Perplexity: 9.5625
# Epoch [1/5], Step [1070/3236], Loss: 2.1542, Perplexity: 8.6208
# Epoch [1/5], Step [1080/3236], Loss: 2.1533, Perplexity: 8.6133
# Epoch [1/5], Step [1090/3236], Loss: 2.1739, Perplexity: 8.7924
# Epoch [1/5], Step [1100/3236], Loss: 2.0111, Perplexity: 7.4714
# Epoch [1/5], Step [1110/3236], Loss: 2.2297, Perplexity: 9.2968
# Epoch [1/5], Step [1120/3236], Loss: 2.0379, Perplexity: 7.6748
# Epoch [1/5], Step [1130/3236], Loss: 2.1609, Perplexity: 8.6793
# Epoch [1/5], Step [1140/3236], Loss: 2.2040, Perplexity: 9.0614
# Epoch [1/5], Step [1150/3236], Loss: 2.1586, Perplexity: 8.6587
# Epoch [1/5], Step [1160/3236], Loss: 2.0381, Perplexity: 7.6757
# Epoch [1/5], Step [1170/3236], Loss: 2.1347, Perplexity: 8.4544
# Epoch [1/5], Step [1180/3236], Loss: 2.1515, Perplexity: 8.5973
# Epoch [1/5], Step [1190/3236], Loss: 2.1200, Perplexity: 8.3312
# Epoch [1/5], Step [1200/3236], Loss: 2.2055, Perplexity: 9.0750
# Epoch [1/5], Step [1210/3236], Loss: 2.1858, Perplexity: 8.8978
# Epoch [1/5], Step [1220/3236], Loss: 2.3147, Perplexity: 10.1221
# Epoch [1/5], Step [1230/3236], Loss: 2.1755, Perplexity: 8.8065
# Epoch [1/5], Step [1240/3236], Loss: 2.2059, Perplexity: 9.0787
# Epoch [1/5], Step [1250/3236], Loss: 2.1513, Perplexity: 8.5959
# Epoch [1/5], Step [1260/3236], Loss: 2.0698, Perplexity: 7.9234
# Epoch [1/5], Step [1270/3236], Loss: 2.1911, Perplexity: 8.9453
# Epoch [1/5], Step [1280/3236], Loss: 2.1299, Perplexity: 8.4137
# Epoch [1/5], Step [1290/3236], Loss: 2.1516, Perplexity: 8.5987
# Epoch [1/5], Step [1300/3236], Loss: 2.0853, Perplexity: 8.0467
# Epoch [1/5], Step [1310/3236], Loss: 2.2584, Perplexity: 9.5681
# Epoch [1/5], Step [1320/3236], Loss: 2.2247, Perplexity: 9.2511
# Epoch [1/5], Step [1330/3236], Loss: 2.1247, Perplexity: 8.3700
# Epoch [1/5], Step [1340/3236], Loss: 2.3797, Perplexity: 10.8013
# Epoch [1/5], Step [1350/3236], Loss: 2.0752, Perplexity: 7.9664
# Epoch [1/5], Step [1360/3236], Loss: 2.0815, Perplexity: 8.0167
# Epoch [1/5], Step [1370/3236], Loss: 2.2394, Perplexity: 9.3880
# Epoch [1/5], Step [1380/3236], Loss: 2.1288, Perplexity: 8.4051
# Epoch [1/5], Step [1390/3236], Loss: 2.2126, Perplexity: 9.1391
# Epoch [1/5], Step [1400/3236], Loss: 2.2103, Perplexity: 9.1186
# Epoch [1/5], Step [1410/3236], Loss: 2.1760, Perplexity: 8.8111
# Epoch [1/5], Step [1420/3236], Loss: 2.1139, Perplexity: 8.2802
# Epoch [1/5], Step [1430/3236], Loss: 2.1622, Perplexity: 8.6906
# Epoch [1/5], Step [1440/3236], Loss: 2.0937, Perplexity: 8.1146
# Epoch [1/5], Step [1450/3236], Loss: 2.0779, Perplexity: 7.9874
# Epoch [1/5], Step [1460/3236], Loss: 2.1062, Perplexity: 8.2168
# Epoch [1/5], Step [1470/3236], Loss: 2.0282, Perplexity: 7.6007
# Epoch [1/5], Step [1480/3236], Loss: 2.1558, Perplexity: 8.6345
# Epoch [1/5], Step [1490/3236], Loss: 1.9854, Perplexity: 7.2818
# Epoch [1/5], Step [1500/3236], Loss: 2.1390, Perplexity: 8.4912
# Epoch [1/5], Step [1510/3236], Loss: 2.1443, Perplexity: 8.5364
# Epoch [1/5], Step [1520/3236], Loss: 2.1433, Perplexity: 8.5275
# Epoch [1/5], Step [1530/3236], Loss: 2.1098, Perplexity: 8.2468
# Epoch [1/5], Step [1540/3236], Loss: 2.3014, Perplexity: 9.9884
# Epoch [1/5], Step [1550/3236], Loss: 2.0478, Perplexity: 7.7507
# Epoch [1/5], Step [1560/3236], Loss: 2.1320, Perplexity: 8.4320
# Epoch [1/5], Step [1570/3236], Loss: 2.1627, Perplexity: 8.6947
# Epoch [1/5], Step [1580/3236], Loss: 2.2668, Perplexity: 9.6484
# Epoch [1/5], Step [1590/3236], Loss: 2.1211, Perplexity: 8.3404
# Epoch [1/5], Step [1600/3236], Loss: 2.0458, Perplexity: 7.7351
# Epoch [1/5], Step [1610/3236], Loss: 1.9595, Perplexity: 7.0960
# Epoch [1/5], Step [1620/3236], Loss: 2.1376, Perplexity: 8.4792
# Epoch [1/5], Step [1630/3236], Loss: 2.0128, Perplexity: 7.4843
# Epoch [1/5], Step [1640/3236], Loss: 2.0643, Perplexity: 7.8797
# Epoch [1/5], Step [1650/3236], Loss: 2.1089, Perplexity: 8.2391
# Epoch [1/5], Step [1660/3236], Loss: 2.1486, Perplexity: 8.5730
# Epoch [1/5], Step [1670/3236], Loss: 2.0211, Perplexity: 7.5464
# Epoch [1/5], Step [1680/3236], Loss: 2.0319, Perplexity: 7.6285
# Epoch [1/5], Step [1690/3236], Loss: 2.1410, Perplexity: 8.5080
# Epoch [1/5], Step [1700/3236], Loss: 2.2687, Perplexity: 9.6671
# Epoch [1/5], Step [1710/3236], Loss: 2.0838, Perplexity: 8.0350
# Epoch [1/5], Step [1720/3236], Loss: 2.1146, Perplexity: 8.2862
# Epoch [1/5], Step [1730/3236], Loss: 2.0636, Perplexity: 7.8744
# Epoch [1/5], Step [1740/3236], Loss: 2.1697, Perplexity: 8.7560
# Epoch [1/5], Step [1750/3236], Loss: 2.1173, Perplexity: 8.3089
# Epoch [1/5], Step [1760/3236], Loss: 2.1401, Perplexity: 8.5001
# Epoch [1/5], Step [1770/3236], Loss: 2.3317, Perplexity: 10.2950
# Epoch [1/5], Step [1780/3236], Loss: 2.1331, Perplexity: 8.4410
# Epoch [1/5], Step [1790/3236], Loss: 2.1291, Perplexity: 8.4072
# Epoch [1/5], Step [1800/3236], Loss: 1.9861, Perplexity: 7.2872
# Epoch [1/5], Step [1810/3236], Loss: 2.2113, Perplexity: 9.1272
# Epoch [1/5], Step [1820/3236], Loss: 2.2832, Perplexity: 9.8078
# Epoch [1/5], Step [1830/3236], Loss: 2.1525, Perplexity: 8.6068
# Epoch [1/5], Step [1840/3236], Loss: 2.0324, Perplexity: 7.6321
# Epoch [1/5], Step [1850/3236], Loss: 2.1088, Perplexity: 8.2382
# Epoch [1/5], Step [1860/3236], Loss: 1.9671, Perplexity: 7.1503
# Epoch [1/5], Step [1870/3236], Loss: 2.0728, Perplexity: 7.9468
# Epoch [1/5], Step [1880/3236], Loss: 2.1253, Perplexity: 8.3754
# Epoch [1/5], Step [1890/3236], Loss: 2.2021, Perplexity: 9.0436
# Epoch [1/5], Step [1900/3236], Loss: 2.0741, Perplexity: 7.9574
# Epoch [1/5], Step [1910/3236], Loss: 2.1751, Perplexity: 8.8027
# Epoch [1/5], Step [1920/3236], Loss: 2.0599, Perplexity: 7.8450
# Epoch [1/5], Step [1930/3236], Loss: 2.1172, Perplexity: 8.3080
# Epoch [1/5], Step [1940/3236], Loss: 2.2225, Perplexity: 9.2305
# Epoch [1/5], Step [1950/3236], Loss: 2.2435, Perplexity: 9.4262
# Epoch [1/5], Step [1960/3236], Loss: 2.0790, Perplexity: 7.9962
# Epoch [1/5], Step [1970/3236], Loss: 2.1406, Perplexity: 8.5042
# Epoch [1/5], Step [1980/3236], Loss: 2.0702, Perplexity: 7.9263
# Epoch [1/5], Step [1990/3236], Loss: 2.1558, Perplexity: 8.6345
# Epoch [1/5], Step [2000/3236], Loss: 2.1123, Perplexity: 8.2675
# Epoch [1/5], Step [2010/3236], Loss: 2.2123, Perplexity: 9.1363
# Epoch [1/5], Step [2020/3236], Loss: 2.0210, Perplexity: 7.5461
# Epoch [1/5], Step [2030/3236], Loss: 2.2050, Perplexity: 9.0705
# Epoch [1/5], Step [2040/3236], Loss: 1.8816, Perplexity: 6.5643
# Epoch [1/5], Step [2050/3236], Loss: 2.2252, Perplexity: 9.2550
# Epoch [1/5], Step [2060/3236], Loss: 2.0913, Perplexity: 8.0955
# Epoch [1/5], Step [2070/3236], Loss: 2.1169, Perplexity: 8.3050
# Epoch [1/5], Step [2080/3236], Loss: 2.1937, Perplexity: 8.9684
# Epoch [1/5], Step [2090/3236], Loss: 2.1250, Perplexity: 8.3725
# Epoch [1/5], Step [2100/3236], Loss: 2.1060, Perplexity: 8.2156
# Epoch [1/5], Step [2110/3236], Loss: 2.1412, Perplexity: 8.5096
# Epoch [1/5], Step [2120/3236], Loss: 2.0141, Perplexity: 7.4942
# Epoch [1/5], Step [2130/3236], Loss: 2.1223, Perplexity: 8.3502
# Epoch [1/5], Step [2140/3236], Loss: 2.0774, Perplexity: 7.9837
# Epoch [1/5], Step [2150/3236], Loss: 2.1110, Perplexity: 8.2564
# Epoch [1/5], Step [2160/3236], Loss: 2.2727, Perplexity: 9.7054
# Epoch [1/5], Step [2170/3236], Loss: 2.2529, Perplexity: 9.5155
# Epoch [1/5], Step [2180/3236], Loss: 2.0559, Perplexity: 7.8137
# Epoch [1/5], Step [2190/3236], Loss: 2.2137, Perplexity: 9.1491
# Epoch [1/5], Step [2200/3236], Loss: 2.1891, Perplexity: 8.9274
# Epoch [1/5], Step [2210/3236], Loss: 2.0913, Perplexity: 8.0954
# Epoch [1/5], Step [2220/3236], Loss: 2.1940, Perplexity: 8.9708
# Epoch [1/5], Step [2230/3236], Loss: 2.1880, Perplexity: 8.9175
# Epoch [1/5], Step [2240/3236], Loss: 2.1915, Perplexity: 8.9488
# Epoch [1/5], Step [2250/3236], Loss: 2.1038, Perplexity: 8.1975
# Epoch [1/5], Step [2260/3236], Loss: 2.1056, Perplexity: 8.2122
# Epoch [1/5], Step [2270/3236], Loss: 2.0448, Perplexity: 7.7273
# Epoch [1/5], Step [2280/3236], Loss: 2.2344, Perplexity: 9.3409
# Epoch [1/5], Step [2290/3236], Loss: 2.0975, Perplexity: 8.1461
# Epoch [1/5], Step [2300/3236], Loss: 2.1402, Perplexity: 8.5015
# Epoch [1/5], Step [2310/3236], Loss: 2.0870, Perplexity: 8.0609
# Epoch [1/5], Step [2320/3236], Loss: 2.1709, Perplexity: 8.7664
# Epoch [1/5], Step [2330/3236], Loss: 1.9331, Perplexity: 6.9110
# Epoch [1/5], Step [2340/3236], Loss: 2.2298, Perplexity: 9.2983
# Epoch [1/5], Step [2350/3236], Loss: 2.0966, Perplexity: 8.1385
# Epoch [1/5], Step [2360/3236], Loss: 2.1499, Perplexity: 8.5839
# Epoch [1/5], Step [2370/3236], Loss: 2.1006, Perplexity: 8.1709
# Epoch [1/5], Step [2380/3236], Loss: 2.0329, Perplexity: 7.6362
# Epoch [1/5], Step [2390/3236], Loss: 2.1989, Perplexity: 9.0149
# Epoch [1/5], Step [2400/3236], Loss: 2.0660, Perplexity: 7.8934
# Epoch [1/5], Step [2410/3236], Loss: 2.0967, Perplexity: 8.1396
# Epoch [1/5], Step [2420/3236], Loss: 2.0659, Perplexity: 7.8925
# Epoch [1/5], Step [2430/3236], Loss: 2.2198, Perplexity: 9.2058
# Epoch [1/5], Step [2440/3236], Loss: 2.1462, Perplexity: 8.5526
# Epoch [1/5], Step [2450/3236], Loss: 2.1648, Perplexity: 8.7126
# Epoch [1/5], Step [2460/3236], Loss: 2.1335, Perplexity: 8.4446
# Epoch [1/5], Step [2470/3236], Loss: 2.0628, Perplexity: 7.8683
# Epoch [1/5], Step [2480/3236], Loss: 2.0733, Perplexity: 7.9510
# Epoch [1/5], Step [2490/3236], Loss: 2.0559, Perplexity: 7.8140
# Epoch [1/5], Step [2500/3236], Loss: 2.2130, Perplexity: 9.1431
# Epoch [1/5], Step [2510/3236], Loss: 2.0814, Perplexity: 8.0160
# Epoch [1/5], Step [2520/3236], Loss: 2.0760, Perplexity: 7.9725
# Epoch [1/5], Step [2530/3236], Loss: 2.0637, Perplexity: 7.8750
# Epoch [1/5], Step [2540/3236], Loss: 2.1765, Perplexity: 8.8151
# Epoch [1/5], Step [2550/3236], Loss: 2.0094, Perplexity: 7.4590
# Epoch [1/5], Step [2560/3236], Loss: 2.2303, Perplexity: 9.3023
# Epoch [1/5], Step [2570/3236], Loss: 2.2255, Perplexity: 9.2580
# Epoch [1/5], Step [2580/3236], Loss: 2.0599, Perplexity: 7.8448
# Epoch [1/5], Step [2590/3236], Loss: 2.2157, Perplexity: 9.1680
# Epoch [1/5], Step [2600/3236], Loss: 2.0224, Perplexity: 7.5565
# Epoch [1/5], Step [2610/3236], Loss: 2.1253, Perplexity: 8.3757
# Epoch [1/5], Step [2620/3236], Loss: 2.1443, Perplexity: 8.5357
# Epoch [1/5], Step [2630/3236], Loss: 2.0392, Perplexity: 7.6842
# Epoch [1/5], Step [2640/3236], Loss: 2.0466, Perplexity: 7.7419
# Epoch [1/5], Step [2650/3236], Loss: 2.0719, Perplexity: 7.9398
# Epoch [1/5], Step [2660/3236], Loss: 2.0306, Perplexity: 7.6185
# Epoch [1/5], Step [2670/3236], Loss: 2.0739, Perplexity: 7.9555
# Epoch [1/5], Step [2680/3236], Loss: 2.1800, Perplexity: 8.8464
# Epoch [1/5], Step [2690/3236], Loss: 2.2772, Perplexity: 9.7489
# Epoch [1/5], Step [2700/3236], Loss: 2.0684, Perplexity: 7.9124
# Epoch [1/5], Step [2710/3236], Loss: 1.9896, Perplexity: 7.3128
# Epoch [1/5], Step [2720/3236], Loss: 2.2245, Perplexity: 9.2492
# Epoch [1/5], Step [2730/3236], Loss: 2.0644, Perplexity: 7.8804
# Epoch [1/5], Step [2740/3236], Loss: 2.0244, Perplexity: 7.5712
# Epoch [1/5], Step [2750/3236], Loss: 2.0915, Perplexity: 8.0967
# Epoch [1/5], Step [2760/3236], Loss: 2.0033, Perplexity: 7.4136
# Epoch [1/5], Step [2770/3236], Loss: 2.2761, Perplexity: 9.7390
# Epoch [1/5], Step [2780/3236], Loss: 2.0304, Perplexity: 7.6170
# Epoch [1/5], Step [2790/3236], Loss: 2.2350, Perplexity: 9.3465
# Epoch [1/5], Step [2800/3236], Loss: 2.0759, Perplexity: 7.9715
# Epoch [1/5], Step [2810/3236], Loss: 2.0092, Perplexity: 7.4571
# Epoch [1/5], Step [2820/3236], Loss: 2.1303, Perplexity: 8.4173
# Epoch [1/5], Step [2830/3236], Loss: 2.0315, Perplexity: 7.6255
# Epoch [1/5], Step [2840/3236], Loss: 2.0859, Perplexity: 8.0515
# Epoch [1/5], Step [2850/3236], Loss: 2.1789, Perplexity: 8.8365
# Epoch [1/5], Step [2860/3236], Loss: 2.0513, Perplexity: 7.7777
# Epoch [1/5], Step [2870/3236], Loss: 2.0959, Perplexity: 8.1331
# Epoch [1/5], Step [2880/3236], Loss: 2.2094, Perplexity: 9.1103
# Epoch [1/5], Step [2890/3236], Loss: 2.2312, Perplexity: 9.3109
# Epoch [1/5], Step [2900/3236], Loss: 2.0602, Perplexity: 7.8475
# Epoch [1/5], Step [2910/3236], Loss: 2.0161, Perplexity: 7.5088
# Epoch [1/5], Step [2920/3236], Loss: 2.0628, Perplexity: 7.8681
# Epoch [1/5], Step [2930/3236], Loss: 1.9630, Perplexity: 7.1208
# Epoch [1/5], Step [2940/3236], Loss: 2.2282, Perplexity: 9.2833
# Epoch [1/5], Step [2950/3236], Loss: 1.9976, Perplexity: 7.3714
# Epoch [1/5], Step [2960/3236], Loss: 2.2213, Perplexity: 9.2195
# Epoch [1/5], Step [2970/3236], Loss: 2.2028, Perplexity: 9.0504
# Epoch [1/5], Step [2980/3236], Loss: 2.2118, Perplexity: 9.1326
# Epoch [1/5], Step [2990/3236], Loss: 2.1027, Perplexity: 8.1883
# Epoch [1/5], Step [3000/3236], Loss: 2.0133, Perplexity: 7.4883
# Epoch [1/5], Step [3010/3236], Loss: 2.0793, Perplexity: 7.9990
# Epoch [1/5], Step [3020/3236], Loss: 2.1440, Perplexity: 8.5332
# Epoch [1/5], Step [3030/3236], Loss: 2.0521, Perplexity: 7.7839
# Epoch [1/5], Step [3040/3236], Loss: 2.2514, Perplexity: 9.5012
# Epoch [1/5], Step [3050/3236], Loss: 2.1780, Perplexity: 8.8284
# Epoch [1/5], Step [3060/3236], Loss: 2.0912, Perplexity: 8.0946
# Epoch [1/5], Step [3070/3236], Loss: 2.0537, Perplexity: 7.7968
# Epoch [1/5], Step [3080/3236], Loss: 2.0965, Perplexity: 8.1373
# Epoch [1/5], Step [3090/3236], Loss: 2.0313, Perplexity: 7.6237
# Epoch [1/5], Step [3100/3236], Loss: 1.9883, Perplexity: 7.3029
# Epoch [1/5], Step [3110/3236], Loss: 2.0429, Perplexity: 7.7127
# Epoch [1/5], Step [3120/3236], Loss: 2.1400, Perplexity: 8.4991
# Epoch [1/5], Step [3130/3236], Loss: 2.0297, Perplexity: 7.6116
# Epoch [1/5], Step [3140/3236], Loss: 2.0319, Perplexity: 7.6284
# Epoch [1/5], Step [3150/3236], Loss: 2.0213, Perplexity: 7.5482
# Epoch [1/5], Step [3160/3236], Loss: 2.0052, Perplexity: 7.4275
# Epoch [1/5], Step [3170/3236], Loss: 2.0268, Perplexity: 7.5897
# Epoch [1/5], Step [3180/3236], Loss: 2.0586, Perplexity: 7.8351
# Epoch [1/5], Step [3190/3236], Loss: 2.0900, Perplexity: 8.0853
# Epoch [1/5], Step [3200/3236], Loss: 2.1429, Perplexity: 8.5245
# Epoch [1/5], Step [3210/3236], Loss: 2.1220, Perplexity: 8.3474
# Epoch [1/5], Step [3220/3236], Loss: 2.0607, Perplexity: 7.8517
# Epoch [1/5], Step [3230/3236], Loss: 2.0524, Perplexity: 7.7865
# Epoch [2/5], Step [0/3236], Loss: 1.9900, Perplexity: 7.3157
# Epoch [2/5], Step [10/3236], Loss: 1.9571, Perplexity: 7.0787
# Epoch [2/5], Step [20/3236], Loss: 1.9628, Perplexity: 7.1192
# Epoch [2/5], Step [30/3236], Loss: 1.9963, Perplexity: 7.3616
# Epoch [2/5], Step [40/3236], Loss: 1.9535, Perplexity: 7.0537
# Epoch [2/5], Step [50/3236], Loss: 2.0283, Perplexity: 7.6008
# Epoch [2/5], Step [60/3236], Loss: 2.0858, Perplexity: 8.0506
# Epoch [2/5], Step [70/3236], Loss: 2.0820, Perplexity: 8.0203
# Epoch [2/5], Step [80/3236], Loss: 1.9799, Perplexity: 7.2420
# Epoch [2/5], Step [90/3236], Loss: 2.0025, Perplexity: 7.4073
# Epoch [2/5], Step [100/3236], Loss: 2.0977, Perplexity: 8.1474
# Epoch [2/5], Step [110/3236], Loss: 2.0276, Perplexity: 7.5957
# Epoch [2/5], Step [120/3236], Loss: 1.9385, Perplexity: 6.9486
# Epoch [2/5], Step [130/3236], Loss: 1.8755, Perplexity: 6.5243
# Epoch [2/5], Step [140/3236], Loss: 1.9644, Perplexity: 7.1309
# Epoch [2/5], Step [150/3236], Loss: 1.9415, Perplexity: 6.9694
# Epoch [2/5], Step [160/3236], Loss: 1.9919, Perplexity: 7.3292
# Epoch [2/5], Step [170/3236], Loss: 1.9594, Perplexity: 7.0951
# Epoch [2/5], Step [180/3236], Loss: 2.0064, Perplexity: 7.4367
# Epoch [2/5], Step [190/3236], Loss: 2.0612, Perplexity: 7.8556
# Epoch [2/5], Step [200/3236], Loss: 2.0528, Perplexity: 7.7900
# Epoch [2/5], Step [210/3236], Loss: 2.0189, Perplexity: 7.5301
# Epoch [2/5], Step [220/3236], Loss: 1.9876, Perplexity: 7.2979
# Epoch [2/5], Step [230/3236], Loss: 2.0607, Perplexity: 7.8518
# Epoch [2/5], Step [240/3236], Loss: 2.0855, Perplexity: 8.0482
# Epoch [2/5], Step [250/3236], Loss: 1.9840, Perplexity: 7.2715
# Epoch [2/5], Step [260/3236], Loss: 1.9360, Perplexity: 6.9311
# Epoch [2/5], Step [270/3236], Loss: 2.1455, Perplexity: 8.5467
# Epoch [2/5], Step [280/3236], Loss: 1.9533, Perplexity: 7.0522
# Epoch [2/5], Step [290/3236], Loss: 1.9413, Perplexity: 6.9675
# Epoch [2/5], Step [300/3236], Loss: 2.0904, Perplexity: 8.0880
# Epoch [2/5], Step [310/3236], Loss: 2.0222, Perplexity: 7.5547
# Epoch [2/5], Step [320/3236], Loss: 2.1248, Perplexity: 8.3712
# Epoch [2/5], Step [330/3236], Loss: 1.9997, Perplexity: 7.3869
# Epoch [2/5], Step [340/3236], Loss: 2.0314, Perplexity: 7.6244
# Epoch [2/5], Step [350/3236], Loss: 2.0213, Perplexity: 7.5484
# Epoch [2/5], Step [360/3236], Loss: 1.9717, Perplexity: 7.1827
# Epoch [2/5], Step [370/3236], Loss: 1.9691, Perplexity: 7.1641
# Epoch [2/5], Step [380/3236], Loss: 2.0915, Perplexity: 8.0973
# Epoch [2/5], Step [390/3236], Loss: 1.9788, Perplexity: 7.2343
# Epoch [2/5], Step [400/3236], Loss: 2.0140, Perplexity: 7.4935
# Epoch [2/5], Step [410/3236], Loss: 2.0763, Perplexity: 7.9750
# Epoch [2/5], Step [420/3236], Loss: 2.0603, Perplexity: 7.8482
# Epoch [2/5], Step [430/3236], Loss: 2.0141, Perplexity: 7.4940
# Epoch [2/5], Step [440/3236], Loss: 2.1416, Perplexity: 8.5132
# Epoch [2/5], Step [450/3236], Loss: 1.9731, Perplexity: 7.1928
# Epoch [2/5], Step [460/3236], Loss: 1.9707, Perplexity: 7.1756
# Epoch [2/5], Step [470/3236], Loss: 2.0835, Perplexity: 8.0325
# Epoch [2/5], Step [480/3236], Loss: 1.8979, Perplexity: 6.6721
# Epoch [2/5], Step [490/3236], Loss: 2.3154, Perplexity: 10.1288
# Epoch [2/5], Step [500/3236], Loss: 1.9552, Perplexity: 7.0652
# Epoch [2/5], Step [510/3236], Loss: 2.0436, Perplexity: 7.7185
# Epoch [2/5], Step [520/3236], Loss: 1.8381, Perplexity: 6.2843
# Epoch [2/5], Step [530/3236], Loss: 2.0182, Perplexity: 7.5246
# Epoch [2/5], Step [540/3236], Loss: 2.0133, Perplexity: 7.4879
# Epoch [2/5], Step [550/3236], Loss: 2.0090, Perplexity: 7.4558
# Epoch [2/5], Step [560/3236], Loss: 2.1435, Perplexity: 8.5290
# Epoch [2/5], Step [570/3236], Loss: 2.0702, Perplexity: 7.9262
# Epoch [2/5], Step [580/3236], Loss: 1.9566, Perplexity: 7.0752
# Epoch [2/5], Step [590/3236], Loss: 1.9827, Perplexity: 7.2625
# Epoch [2/5], Step [600/3236], Loss: 1.9546, Perplexity: 7.0612
# Epoch [2/5], Step [610/3236], Loss: 2.1197, Perplexity: 8.3285
# Epoch [2/5], Step [620/3236], Loss: 2.1741, Perplexity: 8.7943
# Epoch [2/5], Step [630/3236], Loss: 1.9693, Perplexity: 7.1659
# Epoch [2/5], Step [640/3236], Loss: 2.0381, Perplexity: 7.6762
# Epoch [2/5], Step [650/3236], Loss: 1.9137, Perplexity: 6.7782
# Epoch [2/5], Step [660/3236], Loss: 2.0043, Perplexity: 7.4207
# Epoch [2/5], Step [670/3236], Loss: 2.0047, Perplexity: 7.4240
# Epoch [2/5], Step [680/3236], Loss: 1.9608, Perplexity: 7.1049
# Epoch [2/5], Step [690/3236], Loss: 2.0714, Perplexity: 7.9363
# Epoch [2/5], Step [700/3236], Loss: 2.0676, Perplexity: 7.9054
# Epoch [2/5], Step [710/3236], Loss: 2.0320, Perplexity: 7.6295
# Epoch [2/5], Step [720/3236], Loss: 2.1650, Perplexity: 8.7147
# Epoch [2/5], Step [730/3236], Loss: 2.0532, Perplexity: 7.7929
# Epoch [2/5], Step [740/3236], Loss: 1.9206, Perplexity: 6.8249
# Epoch [2/5], Step [750/3236], Loss: 2.0023, Perplexity: 7.4057
# Epoch [2/5], Step [760/3236], Loss: 2.0728, Perplexity: 7.9472
# Epoch [2/5], Step [770/3236], Loss: 2.1152, Perplexity: 8.2910
# Epoch [2/5], Step [780/3236], Loss: 1.8948, Perplexity: 6.6511
# Epoch [2/5], Step [790/3236], Loss: 1.9793, Perplexity: 7.2379
# Epoch [2/5], Step [800/3236], Loss: 1.9585, Perplexity: 7.0889
# Epoch [2/5], Step [810/3236], Loss: 1.9214, Perplexity: 6.8304
# Epoch [2/5], Step [820/3236], Loss: 1.9964, Perplexity: 7.3629
# Epoch [2/5], Step [830/3236], Loss: 1.9840, Perplexity: 7.2719
# Epoch [2/5], Step [840/3236], Loss: 1.8989, Perplexity: 6.6788
# Epoch [2/5], Step [850/3236], Loss: 1.9520, Perplexity: 7.0424
# Epoch [2/5], Step [860/3236], Loss: 1.9979, Perplexity: 7.3736
# Epoch [2/5], Step [870/3236], Loss: 2.0637, Perplexity: 7.8749
# Epoch [2/5], Step [880/3236], Loss: 2.0650, Perplexity: 7.8851
# Epoch [2/5], Step [890/3236], Loss: 1.9645, Perplexity: 7.1314
# Epoch [2/5], Step [900/3236], Loss: 2.0025, Perplexity: 7.4074
# Epoch [2/5], Step [910/3236], Loss: 2.0207, Perplexity: 7.5437
# Epoch [2/5], Step [920/3236], Loss: 2.0853, Perplexity: 8.0467
# Epoch [2/5], Step [930/3236], Loss: 1.9497, Perplexity: 7.0268
# Epoch [2/5], Step [940/3236], Loss: 1.9404, Perplexity: 6.9618
# Epoch [2/5], Step [950/3236], Loss: 2.0173, Perplexity: 7.5177
# Epoch [2/5], Step [960/3236], Loss: 1.9264, Perplexity: 6.8645
# Epoch [2/5], Step [970/3236], Loss: 1.9791, Perplexity: 7.2364
# Epoch [2/5], Step [980/3236], Loss: 1.9793, Perplexity: 7.2380
# Epoch [2/5], Step [990/3236], Loss: 2.1120, Perplexity: 8.2646
# Epoch [2/5], Step [1000/3236], Loss: 1.9790, Perplexity: 7.2357
# Epoch [2/5], Step [1010/3236], Loss: 2.1470, Perplexity: 8.5594
# Epoch [2/5], Step [1020/3236], Loss: 2.0277, Perplexity: 7.5968
# Epoch [2/5], Step [1030/3236], Loss: 1.9511, Perplexity: 7.0364
# Epoch [2/5], Step [1040/3236], Loss: 1.9739, Perplexity: 7.1987
# Epoch [2/5], Step [1050/3236], Loss: 1.9733, Perplexity: 7.1944
# Epoch [2/5], Step [1060/3236], Loss: 2.0911, Perplexity: 8.0940
# Epoch [2/5], Step [1070/3236], Loss: 2.1780, Perplexity: 8.8287
# Epoch [2/5], Step [1080/3236], Loss: 2.0933, Perplexity: 8.1116
# Epoch [2/5], Step [1090/3236], Loss: 2.0438, Perplexity: 7.7197
# Epoch [2/5], Step [1100/3236], Loss: 2.0564, Perplexity: 7.8177
# Epoch [2/5], Step [1110/3236], Loss: 2.0067, Perplexity: 7.4387
# Epoch [2/5], Step [1120/3236], Loss: 1.9941, Perplexity: 7.3454
# Epoch [2/5], Step [1130/3236], Loss: 2.0344, Perplexity: 7.6474
# Epoch [2/5], Step [1140/3236], Loss: 2.0064, Perplexity: 7.4363
# Epoch [2/5], Step [1150/3236], Loss: 2.0105, Perplexity: 7.4668
# Epoch [2/5], Step [1160/3236], Loss: 2.0854, Perplexity: 8.0475
# Epoch [2/5], Step [1170/3236], Loss: 1.8925, Perplexity: 6.6357
# Epoch [2/5], Step [1180/3236], Loss: 1.9046, Perplexity: 6.7168
# Epoch [2/5], Step [1190/3236], Loss: 1.9437, Perplexity: 6.9846
# Epoch [2/5], Step [1200/3236], Loss: 2.0965, Perplexity: 8.1378
# Epoch [2/5], Step [1210/3236], Loss: 2.0544, Perplexity: 7.8019
# Epoch [2/5], Step [1220/3236], Loss: 1.9927, Perplexity: 7.3351
# Epoch [2/5], Step [1230/3236], Loss: 1.8826, Perplexity: 6.5706
# Epoch [2/5], Step [1240/3236], Loss: 1.9735, Perplexity: 7.1959
# Epoch [2/5], Step [1250/3236], Loss: 1.9799, Perplexity: 7.2420
# Epoch [2/5], Step [1260/3236], Loss: 1.9891, Perplexity: 7.3086
# Epoch [2/5], Step [1270/3236], Loss: 1.9477, Perplexity: 7.0124
# Epoch [2/5], Step [1280/3236], Loss: 1.8867, Perplexity: 6.5973
# Epoch [2/5], Step [1290/3236], Loss: 1.9544, Perplexity: 7.0596
# Epoch [2/5], Step [1300/3236], Loss: 2.0965, Perplexity: 8.1375
# Epoch [2/5], Step [1310/3236], Loss: 2.0990, Perplexity: 8.1584
# Epoch [2/5], Step [1320/3236], Loss: 2.0615, Perplexity: 7.8578
# Epoch [2/5], Step [1330/3236], Loss: 2.1335, Perplexity: 8.4444
# Epoch [2/5], Step [1340/3236], Loss: 1.9686, Perplexity: 7.1608
# Epoch [2/5], Step [1350/3236], Loss: 1.9930, Perplexity: 7.3372
# Epoch [2/5], Step [1360/3236], Loss: 2.0256, Perplexity: 7.5805
# Epoch [2/5], Step [1370/3236], Loss: 1.9726, Perplexity: 7.1892
# Epoch [2/5], Step [1380/3236], Loss: 2.0311, Perplexity: 7.6228
# Epoch [2/5], Step [1390/3236], Loss: 2.0249, Perplexity: 7.5750
# Epoch [2/5], Step [1400/3236], Loss: 2.0527, Perplexity: 7.7887
# Epoch [2/5], Step [1410/3236], Loss: 1.9330, Perplexity: 6.9105
# Epoch [2/5], Step [1420/3236], Loss: 1.9779, Perplexity: 7.2275
# Epoch [2/5], Step [1430/3236], Loss: 2.1094, Perplexity: 8.2432
# Epoch [2/5], Step [1440/3236], Loss: 2.0071, Perplexity: 7.4419
# Epoch [2/5], Step [1450/3236], Loss: 2.0173, Perplexity: 7.5179
# Epoch [2/5], Step [1460/3236], Loss: 1.8911, Perplexity: 6.6264
# Epoch [2/5], Step [1470/3236], Loss: 2.0554, Perplexity: 7.8099
# Epoch [2/5], Step [1480/3236], Loss: 2.0938, Perplexity: 8.1160
# Epoch [2/5], Step [1490/3236], Loss: 2.0079, Perplexity: 7.4479
# Epoch [2/5], Step [1500/3236], Loss: 2.0466, Perplexity: 7.7415
# Epoch [2/5], Step [1510/3236], Loss: 1.9549, Perplexity: 7.0631
# Epoch [2/5], Step [1520/3236], Loss: 2.1059, Perplexity: 8.2143
# Epoch [2/5], Step [1530/3236], Loss: 2.0575, Perplexity: 7.8261
# Epoch [2/5], Step [1540/3236], Loss: 2.0254, Perplexity: 7.5790
# Epoch [2/5], Step [1550/3236], Loss: 1.9811, Perplexity: 7.2507
# Epoch [2/5], Step [1560/3236], Loss: 1.9673, Perplexity: 7.1514
# Epoch [2/5], Step [1570/3236], Loss: 2.0280, Perplexity: 7.5990
# Epoch [2/5], Step [1580/3236], Loss: 2.0723, Perplexity: 7.9433
# Epoch [2/5], Step [1590/3236], Loss: 2.1043, Perplexity: 8.2014
# Epoch [2/5], Step [1600/3236], Loss: 2.0164, Perplexity: 7.5109
# Epoch [2/5], Step [1610/3236], Loss: 1.9290, Perplexity: 6.8828
# Epoch [2/5], Step [1620/3236], Loss: 1.9373, Perplexity: 6.9401
# Epoch [2/5], Step [1630/3236], Loss: 2.0584, Perplexity: 7.8331
# Epoch [2/5], Step [1640/3236], Loss: 2.0043, Perplexity: 7.4212
# Epoch [2/5], Step [1650/3236], Loss: 2.0162, Perplexity: 7.5097
# Epoch [2/5], Step [1660/3236], Loss: 2.0416, Perplexity: 7.7032
# Epoch [2/5], Step [1670/3236], Loss: 1.9901, Perplexity: 7.3162
# Epoch [2/5], Step [1680/3236], Loss: 2.0335, Perplexity: 7.6404
# Epoch [2/5], Step [1690/3236], Loss: 2.1819, Perplexity: 8.8635
# Epoch [2/5], Step [1700/3236], Loss: 1.9760, Perplexity: 7.2137
# Epoch [2/5], Step [1710/3236], Loss: 1.8491, Perplexity: 6.3543
# Epoch [2/5], Step [1720/3236], Loss: 1.9666, Perplexity: 7.1463
# Epoch [2/5], Step [1730/3236], Loss: 1.9325, Perplexity: 6.9069
# Epoch [2/5], Step [1740/3236], Loss: 1.9438, Perplexity: 6.9855
# Epoch [2/5], Step [1750/3236], Loss: 2.1051, Perplexity: 8.2076
# Epoch [2/5], Step [1760/3236], Loss: 1.9388, Perplexity: 6.9505
# Epoch [2/5], Step [1770/3236], Loss: 1.9660, Perplexity: 7.1423
# Epoch [2/5], Step [1780/3236], Loss: 1.9812, Perplexity: 7.2514
# Epoch [2/5], Step [1790/3236], Loss: 2.0694, Perplexity: 7.9204
# Epoch [2/5], Step [1800/3236], Loss: 2.0585, Perplexity: 7.8345
# Epoch [2/5], Step [1810/3236], Loss: 2.0794, Perplexity: 7.9998
# Epoch [2/5], Step [1820/3236], Loss: 1.9540, Perplexity: 7.0570
# Epoch [2/5], Step [1830/3236], Loss: 1.9334, Perplexity: 6.9132
# Epoch [2/5], Step [1840/3236], Loss: 1.9003, Perplexity: 6.6879
# Epoch [2/5], Step [1850/3236], Loss: 1.9926, Perplexity: 7.3348
# Epoch [2/5], Step [1860/3236], Loss: 1.9986, Perplexity: 7.3789
# Epoch [2/5], Step [1870/3236], Loss: 2.1501, Perplexity: 8.5860
# Epoch [2/5], Step [1880/3236], Loss: 1.9708, Perplexity: 7.1764
# Epoch [2/5], Step [1890/3236], Loss: 2.1250, Perplexity: 8.3732
# Epoch [2/5], Step [1900/3236], Loss: 1.9860, Perplexity: 7.2860
# Epoch [2/5], Step [1910/3236], Loss: 2.0047, Perplexity: 7.4241
# Epoch [2/5], Step [1920/3236], Loss: 1.8945, Perplexity: 6.6493
# Epoch [2/5], Step [1930/3236], Loss: 2.0297, Perplexity: 7.6117
# Epoch [2/5], Step [1940/3236], Loss: 2.0070, Perplexity: 7.4410
# Epoch [2/5], Step [1950/3236], Loss: 1.9796, Perplexity: 7.2395
# Epoch [2/5], Step [1960/3236], Loss: 2.1141, Perplexity: 8.2817
# Epoch [2/5], Step [1970/3236], Loss: 1.9907, Perplexity: 7.3204
# Epoch [2/5], Step [1980/3236], Loss: 2.0419, Perplexity: 7.7049
# Epoch [2/5], Step [1990/3236], Loss: 2.0599, Perplexity: 7.8449
# Epoch [2/5], Step [2000/3236], Loss: 2.1332, Perplexity: 8.4415
# Epoch [2/5], Step [2010/3236], Loss: 1.8585, Perplexity: 6.4141
# Epoch [2/5], Step [2020/3236], Loss: 2.1007, Perplexity: 8.1722
# Epoch [2/5], Step [2030/3236], Loss: 2.1533, Perplexity: 8.6132
# Epoch [2/5], Step [2040/3236], Loss: 1.8753, Perplexity: 6.5229
# Epoch [2/5], Step [2050/3236], Loss: 2.0672, Perplexity: 7.9027
# Epoch [2/5], Step [2060/3236], Loss: 1.9565, Perplexity: 7.0748
# Epoch [2/5], Step [2070/3236], Loss: 2.0435, Perplexity: 7.7180
# Epoch [2/5], Step [2080/3236], Loss: 2.1049, Perplexity: 8.2060
# Epoch [2/5], Step [2090/3236], Loss: 1.9952, Perplexity: 7.3538
# Epoch [2/5], Step [2100/3236], Loss: 1.9146, Perplexity: 6.7844
# Epoch [2/5], Step [2110/3236], Loss: 2.1554, Perplexity: 8.6313
# Epoch [2/5], Step [2120/3236], Loss: 2.0662, Perplexity: 7.8945
# Epoch [2/5], Step [2130/3236], Loss: 2.0594, Perplexity: 7.8413
# Epoch [2/5], Step [2140/3236], Loss: 1.9933, Perplexity: 7.3394
# Epoch [2/5], Step [2150/3236], Loss: 1.9621, Perplexity: 7.1144
# Epoch [2/5], Step [2160/3236], Loss: 1.9905, Perplexity: 7.3193
# Epoch [2/5], Step [2170/3236], Loss: 2.0066, Perplexity: 7.4379
# Epoch [2/5], Step [2180/3236], Loss: 1.9983, Perplexity: 7.3765
# Epoch [2/5], Step [2190/3236], Loss: 1.8462, Perplexity: 6.3354
# Epoch [2/5], Step [2200/3236], Loss: 2.0032, Perplexity: 7.4128
# Epoch [2/5], Step [2210/3236], Loss: 2.0111, Perplexity: 7.4717
# Epoch [2/5], Step [2220/3236], Loss: 1.9325, Perplexity: 6.9070
# Epoch [2/5], Step [2230/3236], Loss: 1.9450, Perplexity: 6.9936
# Epoch [2/5], Step [2240/3236], Loss: 1.9863, Perplexity: 7.2886
# Epoch [2/5], Step [2250/3236], Loss: 1.9715, Perplexity: 7.1811
# Epoch [2/5], Step [2260/3236], Loss: 1.9654, Perplexity: 7.1379
# Epoch [2/5], Step [2270/3236], Loss: 1.9179, Perplexity: 6.8063
# Epoch [2/5], Step [2280/3236], Loss: 1.9597, Perplexity: 7.0968
# Epoch [2/5], Step [2290/3236], Loss: 2.0421, Perplexity: 7.7066
# Epoch [2/5], Step [2300/3236], Loss: 1.7998, Perplexity: 6.0484
# Epoch [2/5], Step [2310/3236], Loss: 1.9606, Perplexity: 7.1037
# Epoch [2/5], Step [2320/3236], Loss: 2.0926, Perplexity: 8.1061
# Epoch [2/5], Step [2330/3236], Loss: 1.8999, Perplexity: 6.6851
# Epoch [2/5], Step [2340/3236], Loss: 2.0554, Perplexity: 7.8102
# Epoch [2/5], Step [2350/3236], Loss: 2.0242, Perplexity: 7.5700
# Epoch [2/5], Step [2360/3236], Loss: 2.0716, Perplexity: 7.9372
# Epoch [2/5], Step [2370/3236], Loss: 1.9993, Perplexity: 7.3842
# Epoch [2/5], Step [2380/3236], Loss: 1.9456, Perplexity: 6.9975
# Epoch [2/5], Step [2390/3236], Loss: 2.0258, Perplexity: 7.5819
# Epoch [2/5], Step [2400/3236], Loss: 2.0158, Perplexity: 7.5070
# Epoch [2/5], Step [2410/3236], Loss: 2.0062, Perplexity: 7.4347
# Epoch [2/5], Step [2420/3236], Loss: 2.1182, Perplexity: 8.3162
# Epoch [2/5], Step [2430/3236], Loss: 2.0518, Perplexity: 7.7815
# Epoch [2/5], Step [2440/3236], Loss: 1.8155, Perplexity: 6.1444
# Epoch [2/5], Step [2450/3236], Loss: 1.9583, Perplexity: 7.0875
# Epoch [2/5], Step [2460/3236], Loss: 2.0760, Perplexity: 7.9726
# Epoch [2/5], Step [2470/3236], Loss: 1.9977, Perplexity: 7.3719
# Epoch [2/5], Step [2480/3236], Loss: 1.9128, Perplexity: 6.7721
# Epoch [2/5], Step [2490/3236], Loss: 2.0280, Perplexity: 7.5991
# Epoch [2/5], Step [2500/3236], Loss: 1.9553, Perplexity: 7.0663
# Epoch [2/5], Step [2510/3236], Loss: 1.9666, Perplexity: 7.1462
# Epoch [2/5], Step [2520/3236], Loss: 1.9304, Perplexity: 6.8923
# Epoch [2/5], Step [2530/3236], Loss: 2.1502, Perplexity: 8.5865
# Epoch [2/5], Step [2540/3236], Loss: 2.0614, Perplexity: 7.8567
# Epoch [2/5], Step [2550/3236], Loss: 1.9863, Perplexity: 7.2883
# Epoch [2/5], Step [2560/3236], Loss: 2.0088, Perplexity: 7.4546
# Epoch [2/5], Step [2570/3236], Loss: 2.1033, Perplexity: 8.1934
# Epoch [2/5], Step [2580/3236], Loss: 2.0134, Perplexity: 7.4889
# Epoch [2/5], Step [2590/3236], Loss: 1.8911, Perplexity: 6.6265
# Epoch [2/5], Step [2600/3236], Loss: 2.0395, Perplexity: 7.6870
# Epoch [2/5], Step [2610/3236], Loss: 1.9392, Perplexity: 6.9534
# Epoch [2/5], Step [2620/3236], Loss: 2.0529, Perplexity: 7.7906
# Epoch [2/5], Step [2630/3236], Loss: 1.8776, Perplexity: 6.5381
# Epoch [2/5], Step [2640/3236], Loss: 1.9788, Perplexity: 7.2341
# Epoch [2/5], Step [2650/3236], Loss: 2.0209, Perplexity: 7.5455
# Epoch [2/5], Step [2660/3236], Loss: 2.0233, Perplexity: 7.5632
# Epoch [2/5], Step [2670/3236], Loss: 2.0858, Perplexity: 8.0510
# Epoch [2/5], Step [2680/3236], Loss: 1.9930, Perplexity: 7.3375
# Epoch [2/5], Step [2690/3236], Loss: 2.0507, Perplexity: 7.7731
# Epoch [2/5], Step [2700/3236], Loss: 2.0146, Perplexity: 7.4980
# Epoch [2/5], Step [2710/3236], Loss: 1.9768, Perplexity: 7.2197
# Epoch [2/5], Step [2720/3236], Loss: 1.9854, Perplexity: 7.2818
# Epoch [2/5], Step [2730/3236], Loss: 2.0325, Perplexity: 7.6331
# Epoch [2/5], Step [2740/3236], Loss: 2.0527, Perplexity: 7.7891
# Epoch [2/5], Step [2750/3236], Loss: 1.9671, Perplexity: 7.1501
# Epoch [2/5], Step [2760/3236], Loss: 1.8747, Perplexity: 6.5192
# Epoch [2/5], Step [2770/3236], Loss: 1.9426, Perplexity: 6.9770
# Epoch [2/5], Step [2780/3236], Loss: 2.0328, Perplexity: 7.6354
# Epoch [2/5], Step [2790/3236], Loss: 2.0005, Perplexity: 7.3927
# Epoch [2/5], Step [2800/3236], Loss: 2.0891, Perplexity: 8.0777
# Epoch [2/5], Step [2810/3236], Loss: 2.0606, Perplexity: 7.8504
# Epoch [2/5], Step [2820/3236], Loss: 2.0900, Perplexity: 8.0847
# Epoch [2/5], Step [2830/3236], Loss: 2.0086, Perplexity: 7.4527
# Epoch [2/5], Step [2840/3236], Loss: 2.1276, Perplexity: 8.3946
# Epoch [2/5], Step [2850/3236], Loss: 1.9535, Perplexity: 7.0536
# Epoch [2/5], Step [2860/3236], Loss: 2.0178, Perplexity: 7.5218
# Epoch [2/5], Step [2870/3236], Loss: 1.9188, Perplexity: 6.8126
# Epoch [2/5], Step [2880/3236], Loss: 2.0230, Perplexity: 7.5610
# Epoch [2/5], Step [2890/3236], Loss: 2.0082, Perplexity: 7.4501
# Epoch [2/5], Step [2900/3236], Loss: 2.0520, Perplexity: 7.7833
# Epoch [2/5], Step [2910/3236], Loss: 1.9344, Perplexity: 6.9196
# Epoch [2/5], Step [2920/3236], Loss: 2.0117, Perplexity: 7.4762
# Epoch [2/5], Step [2930/3236], Loss: 2.0261, Perplexity: 7.5841
# Epoch [2/5], Step [2940/3236], Loss: 1.9492, Perplexity: 7.0227
# Epoch [2/5], Step [2950/3236], Loss: 2.0201, Perplexity: 7.5390
# Epoch [2/5], Step [2960/3236], Loss: 2.0063, Perplexity: 7.4355
# Epoch [2/5], Step [2970/3236], Loss: 1.8769, Perplexity: 6.5332
# Epoch [2/5], Step [2980/3236], Loss: 1.9093, Perplexity: 6.7484
# Epoch [2/5], Step [2990/3236], Loss: 1.9819, Perplexity: 7.2566
# Epoch [2/5], Step [3000/3236], Loss: 1.9876, Perplexity: 7.2983
# Epoch [2/5], Step [3010/3236], Loss: 2.0517, Perplexity: 7.7815
# Epoch [2/5], Step [3020/3236], Loss: 1.9963, Perplexity: 7.3620
# Epoch [2/5], Step [3030/3236], Loss: 2.0529, Perplexity: 7.7902
# Epoch [2/5], Step [3040/3236], Loss: 2.0894, Perplexity: 8.0797
# Epoch [2/5], Step [3050/3236], Loss: 2.0621, Perplexity: 7.8626
# Epoch [2/5], Step [3060/3236], Loss: 1.9962, Perplexity: 7.3613
# Epoch [2/5], Step [3070/3236], Loss: 1.9844, Perplexity: 7.2744
# Epoch [2/5], Step [3080/3236], Loss: 2.0181, Perplexity: 7.5243
# Epoch [2/5], Step [3090/3236], Loss: 2.0738, Perplexity: 7.9548
# Epoch [2/5], Step [3100/3236], Loss: 2.0383, Perplexity: 7.6776
# Epoch [2/5], Step [3110/3236], Loss: 1.9923, Perplexity: 7.3324
# Epoch [2/5], Step [3120/3236], Loss: 2.0702, Perplexity: 7.9267
# Epoch [2/5], Step [3130/3236], Loss: 1.9952, Perplexity: 7.3534
# Epoch [2/5], Step [3140/3236], Loss: 1.9508, Perplexity: 7.0340
# Epoch [2/5], Step [3150/3236], Loss: 2.0842, Perplexity: 8.0378
# Epoch [2/5], Step [3160/3236], Loss: 2.0466, Perplexity: 7.7418
# Epoch [2/5], Step [3170/3236], Loss: 1.9496, Perplexity: 7.0260
# Epoch [2/5], Step [3180/3236], Loss: 1.9892, Perplexity: 7.3093
# Epoch [2/5], Step [3190/3236], Loss: 1.8964, Perplexity: 6.6621
# Epoch [2/5], Step [3200/3236], Loss: 1.9579, Perplexity: 7.0847
# Epoch [2/5], Step [3210/3236], Loss: 2.0204, Perplexity: 7.5413
# Epoch [2/5], Step [3220/3236], Loss: 1.9400, Perplexity: 6.9584
# Epoch [2/5], Step [3230/3236], Loss: 1.9838, Perplexity: 7.2702
# Epoch [3/5], Step [0/3236], Loss: 1.9193, Perplexity: 6.8160
# Epoch [3/5], Step [10/3236], Loss: 1.9055, Perplexity: 6.7225
# Epoch [3/5], Step [20/3236], Loss: 1.9322, Perplexity: 6.9047
# Epoch [3/5], Step [30/3236], Loss: 1.9177, Perplexity: 6.8056
# Epoch [3/5], Step [40/3236], Loss: 1.8789, Perplexity: 6.5462
# Epoch [3/5], Step [50/3236], Loss: 1.9044, Perplexity: 6.7151
# Epoch [3/5], Step [60/3236], Loss: 1.8335, Perplexity: 6.2559
# Epoch [3/5], Step [70/3236], Loss: 1.8709, Perplexity: 6.4939
# Epoch [3/5], Step [80/3236], Loss: 1.9557, Perplexity: 7.0686
# Epoch [3/5], Step [90/3236], Loss: 1.9448, Perplexity: 6.9922
# Epoch [3/5], Step [100/3236], Loss: 1.8670, Perplexity: 6.4685
# Epoch [3/5], Step [110/3236], Loss: 1.9655, Perplexity: 7.1383
# Epoch [3/5], Step [120/3236], Loss: 1.9508, Perplexity: 7.0341
# Epoch [3/5], Step [130/3236], Loss: 1.9218, Perplexity: 6.8331
# Epoch [3/5], Step [140/3236], Loss: 1.9108, Perplexity: 6.7587
# Epoch [3/5], Step [150/3236], Loss: 1.8583, Perplexity: 6.4125
# Epoch [3/5], Step [160/3236], Loss: 1.8493, Perplexity: 6.3551

# %% [markdown]
# ## 위까지는 학습
# * 학습과정이 꽤 오래 걸림. 4시간 정도?
# * model를 저장해두었으니, 저장된 모델을 불러와서 test하면 된다.
# * model inference 또는 prediction (test image)는 다른 notebook에서 분리해서 진행하자.

# %%
image_file_path = 'sample.jpg'
 

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
 

def load_image(image_file_path, transform=None):
    img = Image.open(image_file_path).convert('RGB')
    img = img.resize([224, 224], Image.LANCZOS)
    
    if transform is not None:
        img = transform(img).unsqueeze(0)
    
    return img
 

# Image preprocessing
transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize((0.485, 0.456, 0.406), 
                         (0.229, 0.224, 0.225))])


# Load vocabulary wrapper
with open('data_dir/vocabulary.pkl', 'rb') as f:
    vocabulary = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/hyunsu/Documents/GitHub/pytorch-tutorial/DL_torch_book/Ch02_LSTM_CNN.ipynb Cell 14 in <cell line: 26>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu223/home/hyunsu/Documents/GitHub/pytorch-tutorial/DL_torch_book/Ch02_LSTM_CNN.ipynb#ch0000013vscode-remote?line=18'>19</a> transform = transforms.Compose([
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu223/home/hyunsu/Documents/GitHub/pytorch-tutorial/DL_torch_book/Ch02_LSTM_CNN.ipynb#ch0000013vscode-remote?line=19'>20</a>     transforms.ToTensor(),
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu223/home/hyunsu/Documents/GitHub/pytorch-tutorial/DL_torch_book/Ch02_LSTM_CNN.ipynb#ch0000013vscode-remote?line=20'>21</a>     transforms.Normalize((0.485, 0.456, 0.406),
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu223/home/hyunsu/Documents/GitHub/pytorch-tutorial/DL_torch_book/Ch02_LSTM_CNN.ipynb#ch0000013vscode-remote?line=21'>22</a>                          (0.229, 0.224, 0.225))])
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu223/home/hyunsu/Documents/GitHub/pytorch-tutorial/DL_torch_book/Ch02_LSTM_CNN.ipynb#ch0000013vscode-remote?line=24'>25</a> # Load vocabulary wrapper
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bubuntu223/home/hyunsu/Documents/GitHub/pytorch-tutorial/DL_torch_book/Ch02_LSTM_CNN.ipynb#ch0000013vscode-remote?line=25'>26</a> with open('data_dir/vocabulary.pkl', 'rb') as f:
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu223/home/hyunsu/Documents/GitHub/pytorch-tutorial/DL_torch_book/Ch02_LSTM_CNN.ipynb#ch0000013vscode-remote?line=26'>27</a>     vocabulary = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_dir/vocabulary.pkl'
